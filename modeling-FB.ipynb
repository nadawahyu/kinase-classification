# %% [markdown]
# # Introduction
#
# Basically we are trying to find the best algorithm to classify the inhibitor types in our binary dataset from KinCoRe that we preprocessed. Here, we are trying out using Logistic Regression, Support Vector Machine, and Random Forest.
#
# The workflow is as follows:
# 1. load packages, directory, and dataset
# 2. find the best combination of sampling and standardization/normalization methods that yields the best baseline model
# 3. run hyperparameter tuning for our model to get the highest metrics score
# 4. repeat with different algorithms

# %% [markdown]
# # Load dataset and directories

# %%
# general data analysis packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# file management packages
import csv, sys
import os
import copy
import pickle

# sampling
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler, NearMiss

# modeling
from sklearn import preprocessing, model_selection, feature_selection, metrics
from sklearn.feature_selection import f_classif, SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MaxAbsScaler, MinMaxScaler, Normalizer, PowerTransformer, QuantileTransformer, RobustScaler, StandardScaler
from sklearn.exceptions import ConvergenceWarning
from sklearn.feature_selection import SelectFromModel
from sklearn.inspection import permutation_importance

# misc
from textwrap import wrap
import time

# %%
os.chdir('../data')

# %%
data_fb = pd.read_csv('data_binding_fp-03.csv').drop(columns=['Unnamed: 0'])
data_fb = data_fb.replace({'Type1.5_Back':'Type1.5', 'Type1.5_Front':'Type1.5'})
data_fb
# Out:
#                                              lig_smiles LigandType  lig_at  \
# 0     CNC(=O)c1c(C)oc2cc(Oc3ccnc4cc(OCCN5CCOCC5)ccc3...    Type1.5    2169
# 1                O=C(O)c1cc2cc3ccc4oc(C(=O)O)cc4c3cc2o1      Type1     313
# 2                O=C(O)c1cc2cc3ccc4oc(C(=O)O)cc4c3cc2o1      Type1     332
# 3        COc1cc(Nc2nccc(Nc3cnc4ccccc4c3)n2)ccc1N1CCOCC1      Type1   60001
# 4     Cc1cc(Nc2nn(C(C)C)c(=O)c3cc(N4CCN(C)CC4)ccc23)...      Type1       1
# ...                                                 ...        ...     ...
# 4764  O=C(O)c1ccc(Nc2ncc3c(n2)-c2ccc(Cl)cc2C(c2c(F)c...      Type1    1390
# 4765  O=C(O)c1ccc(Nc2ncc3c(n2)-c2ccc(Cl)cc2C(c2c(F)c...      Type1    1392
# 4766  O=C(O)c1ccc(Nc2ncc3c(n2)-c2ccc(Cl)cc2C(c2c(F)c...      Type1    1389
# 4767  O=C(O)c1ccc(Nc2ncc3c(n2)-c2ccc(Cl)cc2C(c2c(F)c...      Type1    1001
# 4768  NC(=O)c1cnc2ccn(S(=O)(=O)c3ccccc3[N+](=O)[O-])...      Type1    2347
#
#       nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A     SpAD_A   SpMAD_A  ...  \
# 0         0      1  45.033552  2.486988  4.905553  45.033552  1.324516  ...
# 1         2      0  28.466792  2.532439  4.962680  28.466792  1.293945  ...
# 2         2      0  28.466792  2.532439  4.962680  28.466792  1.293945  ...
# 3         0      0  43.138904  2.390528  4.781057  43.138904  1.348091  ...
# 4         0      1  36.178567  2.495953  4.988216  36.178567  1.292092  ...
# ...     ...    ...        ...       ...       ...        ...       ...  ...
# 4764      1      0  44.089568  2.510581  4.966182  44.089568  1.296752  ...
# 4765      1      0  44.089568  2.510581  4.966182  44.089568  1.296752  ...
# 4766      1      0  44.089568  2.510581  4.966182  44.089568  1.296752  ...
# 4767      1      0  44.089568  2.510581  4.966182  44.089568  1.296752  ...
# 4768      0      0  30.124798  2.529651  4.996022  30.124798  1.255200  ...
#
#          SRW09      SRW10     TSRW10          MW        AMW  WPath  WPol  \
# 0     7.034388  10.469568  84.750063  461.195071   7.560575   4081    55
# 1     7.544861  10.229224  72.883345  296.032088   9.867736   1015    37
# 2     7.544861  10.229224  72.883345  296.032088   9.867736   1015    37
# 3     0.000000  10.351789  68.049732  428.196074   7.646358   3385    50
# 4     6.529419  10.341194  77.189895  381.227708   6.931413   2015    46
# ...        ...        ...        ...         ...        ...    ...   ...
# 4764  5.379897  10.553649  78.788838  476.085160   9.716024   3464    63
# 4765  5.379897  10.553649  78.788838  476.085160   9.716024   3464    63
# 4766  5.379897  10.553649  78.788838  476.085160   9.716024   3464    63
# 4767  5.379897  10.553649  78.788838  476.085160   9.716024   3464    63
# 4768  6.861711  10.294955  73.088723  346.037190  10.177564   1240    42
#
#       Zagreb1  Zagreb2  mZagreb2
# 0       182.0    216.0  7.500000
# 1       126.0    154.0  4.583333
# 2       126.0    154.0  4.583333
# 3       170.0    199.0  7.083333
# 4       152.0    181.0  6.000000
# ...       ...      ...       ...
# 4764    186.0    223.0  7.305556
# 4765    186.0    223.0  7.305556
# 4766    186.0    223.0  7.305556
# 4767    186.0    223.0  7.305556
# 4768    130.0    157.0  5.138889
#
# [4769 rows x 792 columns]

# %%
sns.countplot(data_fb, x='LigandType')
# Out:
# <AxesSubplot:xlabel='LigandType', ylabel='count'>

# %% [markdown]
# from here we can see that there are several columns that need to be dropped for the next step, such as `Unnamed: 0` and `lig_smiles`. The column `LigandType` needs to be separated as a target. The rest (209 columns) are features we'll use in the model.

# %% [markdown]
# # 0. preprocess data
#
# workflow in this step is the following:
# 1. drop duplicate and null rows
# 2. drop feature that begins with `Unnamed` (since it was generated automatically when we did not reset the index in the last step before saving the data from the previous step into csv)
# 3. encode target using integer (0,1)
# 4. separate features and target
# 5. remove features which values don't have variation
# 6. remove feature that has low correlation with other features
# 7. split data into train-validation and test set
# 8. split data into train and validation set

# %%
def data_preprocessing(data,
                       target='LigandType', 
                       col_to_drop=['lig_smiles'],
                       test_size=0.2, 
                       val_size=0.2, 
                       random_state=0,
                       anova=True,
                       ):
    '''
    preprocess data from the previous workflow

    Args:
    ----------
      data: pd.DataFrame
        the input data to be preprocesed
      target: str
        target column for the model
      col_to_drop: list
        list of columns to drop
      test_size: float
        test size from the whole input data
      val_size: float
        validation set size from the whole input data
      anova: bool
        initial feature selection option using ANOVA

    Returns:
    ----------
      X_train, X_val, X_test, y_train, y_val, y_test: np.array
        the respective train, validation and test sets
      descnm: np.array
        feature names
    '''

    # drop duplicate rows
    data_ = data.drop_duplicates().dropna()

    # drop cols with 'unnamed'
    colidx_to_drop = [i for i in data.columns if 'Unnamed' in i]

    #encode target
    to_mask = {}

    for i,j in enumerate(data_[target].unique()):
        to_mask.update({j:i})

    data_ = data_.replace(to_mask)

    # separate x and y
    X = data_.loc[:, data_.columns.difference(col_to_drop+[target]+colidx_to_drop)]
    y = data_[target]

    # remove features that don't have variation
    X_out = X.loc[:,X.apply(pd.Series.nunique) != 1]
    mask = X_out.applymap(lambda x: isinstance(x, (int, float)))
    X_out2 = X_out.where(mask)
    X = X_out2.dropna(axis=1)

    if anova == True:
      # anova feature selection
      f_stat, p_val, = f_classif(X, y)

      # get index which probability is lower than p = 0.05
      idx = [i for i,j in enumerate(p_val) if j < 0.05]
      # select column with respective index
      X = X.iloc[:,idx]
    else:
      pass

    # split train-validation and test
    X_trainval, X_test, y_trainval, y_test = model_selection.train_test_split(X, y, test_size = test_size, random_state=random_state, stratify=y)
    # split train and validation
    X_train, X_val, y_train, y_val = model_selection.train_test_split(X_trainval, y_trainval, test_size = val_size/(1-val_size), random_state=random_state, stratify=y_trainval)

    descnm = np.array(X_train.columns)
    X_train = np.array(X_train)
    X_val = np.array(X_val)
    X_test = np.array(X_test)
    y_train = np.array(y_train)
    y_val = np.array(y_val)
    y_test = np.array(y_test)

    #return X_trainval, X_test, y_trainval, y_test
    return X_train, X_val, X_test, y_train, y_val, y_test, descnm

# %%
X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_fb)

# %%
print(len(y_train))
print(len(y_val))
print(len(y_test))
print(len(y_train)+len(y_val)+len(y_test))
# Out:
# 2859
# 953
# 953
# 4765

# %%
print(f'0 = {len([i for i in y_train if i == 0])}')
print(f'1 = {len([i for i in y_train if i == 1])}')

print(f'0 = {len([i for i in y_val if i == 0])}')
print(f'1 = {len([i for i in y_val if i == 1])}')

print(f'0 = {len([i for i in y_test if i == 0])}')
print(f'1 = {len([i for i in y_test if i == 1])}')
# Out:
# 0 = 292
# 1 = 2266
# 0 = 97
# 1 = 755
# 0 = 97
# 1 = 755

# %% [markdown]
# # 1. find combination of sampling and standardization methods for a baseline model

# %%
def find_model(X_train, y_train, X_val, y_val,
                algorithm = 'logreg',
                multiclass = False,
                kernel = 'rbf',
                solver='liblinear',
                max_iter=10000,
                scaling = True,
                random_state=0):
    '''
    Find the best combination of sampling and
    standardization methods as a baseline model.

    Args:
    ----------
        X_train, y_train, X_val, y_val: np.array or pd.DataFrame or pd.Series
            Training and validation data and its targts
        algorithm: str
            The algorithm to use. Available are:
            - Logistic regression: 'LogisticRegression'
            - Support vector machine: 'SVC'
            - Random forest: 'RandomForestClassification'
        multiclass: bool
            Determining whether the classification is binary or multiclass.
            if `True` then the average metrics is computed as weighted
            if `False` then the average metrics is computed as binary
        kernel: str
            only applies in support vector machine. 
            The kernel you wish to run.
        solver: str
            only applies in logistic regression. 
            The solver you wish to run. Default is 'liblinear'.
        #sampling: str
        #    sampling method you wish to use. Available are:
        #    - smote
        #    - random_over
        #    - random_under
        scaling: bool
            scaling (standardization/normalization) of the data.

    Returns:
    ----------
        df_find_model
            A DataFrame of the scores between different sampling and scaling methods 
            across metrics of the training and validation data
    '''

    def model_(X_train, y_train, X_val, y_val,
                      algorithm = algorithm,
                      multiclass = multiclass,
                      kernel = kernel,
                      solver = solver,
                      sampling = 'SMOTE',
                      max_iter=max_iter,
                      scaling = scaling,
                      random_state=random_state):
        '''
        Find the best combination of sampling and
        standardization methods as a baseline model.

        Args:
        ----------
            X_train, y_train, X_val, y_val: np.array or pd.DataFrame or pd.Series
                Training and validation data and its targts
            algorithm: str
                The algorithm to use. Available are:
                - Logistic regression: 'logreg'
                - Support vector machine: 'svm'
                - Random forest: 'rf'
            multiclass: bool
                Determining whether the classification is binary or multiclass.
                if `True` then the average metrics is computed as weighted
                if `False` then the average metrics is computed as binary
            kernel: str
                only applies in support vector machine. 
                The kernel you wish to run.
            solver: str
                only applies in logistic regression. 
                The solver you wish to run. Default is 'liblinear'.
            sampling: str
                sampling method you wish to use. Available are:
                - smote
                - random_over
                - random_under
            scaling: bool
                scaling (standardization/normalization) of the data.

        Returns:
        ----------
            dict
                A dictionary of the scores between different sampling and scaling methods 
                across metrics of the training and validation data
        '''

        if type(sampling) == str:
            sampling = [sampling]

        for i in sampling:
            if i == 'RandomUnderSampler':
                X_train, y_train  = RandomUnderSampler(random_state=random_state).fit_resample(X_train, y_train)
            elif i == 'RandomOverSampler':
                X_train, y_train  = RandomOverSampler(random_state=random_state).fit_resample(X_train, y_train)
            elif i == 'SMOTE':
                X_train, y_train = SMOTE(random_state=random_state).fit_resample(X_train, y_train)
            else:
                pass
        
        if algorithm == 'LogisticRegression':
            model = LogisticRegression(solver=solver, random_state=random_state, max_iter=max_iter)
        elif algorithm == 'SVC':
            model = SVC(kernel=kernel, random_state=random_state)
        else:
            model = RandomForestClassifier(random_state=random_state)
            scaling = False

        # scaling
        if scaling == False:
            train_scaled = {'none':X_train}
            val_scaled = {'none':X_val}
        else:
            scaler = preprocessing.MaxAbsScaler()
            X_train_MAS = scaler.fit_transform(X_train)
            X_val_MAS = scaler.transform(X_val)

            scaler = preprocessing.MinMaxScaler()
            X_train_MMS = scaler.fit_transform(X_train)
            X_val_MMS = scaler.transform(X_val)

            scaler = preprocessing.StandardScaler()
            X_train_SS = scaler.fit_transform(X_train)
            X_val_SS = scaler.transform(X_val)

            scaler = preprocessing.Normalizer()
            X_train_NORM = scaler.fit_transform(X_train)
            X_val_NORM = scaler.transform(X_val)

            scaler = preprocessing.MaxAbsScaler()
            X_train_NMAS = scaler.fit_transform(X_train_NORM)
            X_val_NMAS = scaler.transform(X_val_NORM)

            scaler = preprocessing.MinMaxScaler()
            X_train_NMMS = scaler.fit_transform(X_train_NORM)
            X_val_NMMS = scaler.transform(X_val_NORM)

            scaler = preprocessing.StandardScaler()
            X_train_NSS = scaler.fit_transform(X_train_NORM)
            X_val_NSS = scaler.transform(X_val_NORM)

            scaler = preprocessing.Normalizer()
            X_train_MASNORM = scaler.fit_transform(X_train_MAS)
            X_val_MASNORM = scaler.transform(X_val_MAS)

            scaler = preprocessing.Normalizer()
            X_train_MMSNORM = scaler.fit_transform(X_train_MMS)
            X_val_MMSNORM = scaler.transform(X_val_MMS)

            scaler = preprocessing.Normalizer()
            X_train_SSNORM = scaler.fit_transform(X_train_SS)
            X_val_SSNORM = scaler.transform(X_val_SS)
            

            train_scaled = {
                'none':X_train,
                'MaxAbsScaler':X_train_MAS,
                'MinMaxScaler':X_train_MMS,
                'StandardScaler':X_train_SS,
                'Normalizer':X_train_NORM,
                'Normalizer + MaxAbsScaler':X_train_NMAS,
                'Normalizer + MinMaxScaler':X_train_NMMS,
                'Normalizer + StandardScaler':X_train_NSS,
                'MaxAbsScaler + Normalizer':X_train_MASNORM,
                'MinMaxScaler + Normalizer':X_train_MMSNORM,
                'StandardScaler + Normalizer':X_train_SSNORM,
                }
            
            val_scaled = {
                'none':X_val,
                'MaxAbsScaler':X_val_MAS,
                'MinMaxScaler':X_val_MMS,
                'StandardScaler':X_val_SS,
                'Normalizer':X_val_NORM,
                'Normalizer + MaxAbsScaler':X_val_NMAS,
                'Normalizer + MinMaxScaler':X_val_NMMS,
                'Normalizer + StandardScaler':X_val_NSS,
                'MaxAbsScaler + Normalizer':X_val_MASNORM,
                'MinMaxScaler + Normalizer':X_val_MMSNORM,
                'StandardScaler + Normalizer':X_val_SSNORM,
                }

        output_dict= {
            'sampling': [],
            'scaling': [],
            'train_accuracy': [],
            'train_f1': [],
            'train_ba':[],
            'train_mcc':[],
            'train_cf': [],
            'val_accuracy':[],
            'val_f1':[],
            'val_ba':[],
            'val_mcc':[],
            'val_cf': [],
        }

        for sampl in sampling:
            for scaler, scaled in train_scaled.items():
                for v_scaled in val_scaled.values():
                    fit = model.fit(scaled, y_train)
                    y_pred = fit.predict(scaled)
                    y_val_pred = fit.predict(v_scaled)


                    # calculate statistical metrics accuracy for training set
                    train_accuracy = metrics.accuracy_score(y_train, y_pred)
                    val_accuracy = metrics.accuracy_score(y_val, y_val_pred)

                    if multiclass == True:
                        # calculate statistical metrics for training set
                        train_f1 = metrics.f1_score(y_train, y_pred, average = 'weighted')
                        train_ba = metrics.balanced_accuracy_score(y_train, y_pred)
                        train_mcc = metrics.matthews_corrcoef(y_train, y_pred)
                        train_cf = metrics.confusion_matrix(y_train, y_pred)

                        # calculate statistical metrics for val set
                        val_f1 = metrics.f1_score(y_val, y_val_pred, average = 'weighted')
                        val_ba = metrics.balanced_accuracy_score(y_val, y_val_pred)
                        val_mcc = metrics.matthews_corrcoef(y_val, y_val_pred)
                        val_cf = metrics.confusion_matrix(y_val, y_val_pred)
                    else:
                        # calculate statistical metrics for training set
                        train_f1 = metrics.f1_score(y_train, y_pred, average = 'binary')
                        train_ba = metrics.balanced_accuracy_score(y_train, y_pred)
                        train_mcc = metrics.matthews_corrcoef(y_train, y_pred)
                        train_cf = metrics.confusion_matrix(y_train, y_pred)

                        # calculate statistical metrics for val set
                        val_f1 = metrics.f1_score(y_val, y_val_pred, average = 'binary')
                        val_ba = metrics.balanced_accuracy_score(y_val, y_val_pred)
                        val_mcc = metrics.matthews_corrcoef(y_val, y_val_pred)
                        val_cf = metrics.confusion_matrix(y_val, y_val_pred)


                    output_dict['sampling'].append(sampl)
                    output_dict['scaling'].append(scaler)
                    # train metrics
                    output_dict['train_accuracy'].append(train_accuracy)
                    output_dict['train_f1'].append(train_f1)
                    output_dict['train_ba'].append(train_ba)
                    output_dict['train_mcc'].append(train_mcc)
                    output_dict['train_cf'].append(train_cf)
                    # val metrics
                    output_dict['val_accuracy'].append(val_accuracy)
                    output_dict['val_f1'].append(val_f1)
                    output_dict['val_ba'].append(val_ba)
                    output_dict['val_mcc'].append(val_mcc)
                    output_dict['val_cf'].append(val_cf)
        return output_dict

    
    model_smote = model_(X_train, y_train, X_val, y_val, sampling = 'SMOTE', kernel=kernel, algorithm=algorithm, scaling=scaling, solver=solver, max_iter=max_iter)
    model_under = model_(X_train, y_train, X_val, y_val, sampling = 'RandomUnderSampler', kernel=kernel, algorithm=algorithm, scaling=scaling, solver=solver, max_iter=max_iter)
    model_over = model_(X_train, y_train, X_val, y_val, sampling = 'RandomOverSampler', kernel=kernel, algorithm=algorithm, scaling=scaling, solver=solver, max_iter=max_iter)
    model_nosampling = model_(X_train, y_train, X_val, y_val, sampling = 'no_sampling', kernel=kernel, algorithm=algorithm, scaling=scaling, solver=solver, max_iter=max_iter)

    df_model = []
    for i in [model_smote, model_under, model_over, model_nosampling]:
        df = pd.DataFrame.from_dict(i)
        df_model.append(df)

    df_find_model = pd.concat(df_model, ignore_index=True)
    df_find_model = df_find_model.sort_values(by=['val_ba', 'val_mcc', 'train_ba', 'train_mcc'], ascending=False).round(3)
    #df_find_model.to_csv('linreg_allo_rdkit_model_baseline.csv')

    return df_find_model

# %%
#find_model(X_train, y_train, X_val, y_val, kernel='rbf', algorithm='svm')

# %% [markdown]
# get new standardized and sampled data

# %%
def sampled_scaled(X_train, y_train, 
            sampling = 'SMOTE',
            scaling = True,
            random_state=0):
    '''
    Find the best combination of sampling and
    standardization methods as a baseline model.

    Args:
    ----------
        X_train, y_train, X_val, y_val: np.array or pd.DataFrame or pd.Series
            Training and validation data and its targts
        sampling: str
            sampling method you wish to use. Available are:
            - smote
            - random_over
            - random_under
        scaling: bool
            scaling (standardization/normalization) of the data.

    Returns:
    ----------
        X_train, y_train, X_val, y_val: np.array or pd.DataFrame or pd.Series
            Training data and its targets after sampled and scaled
    '''

    if type(sampling) == str:
        sampling = [sampling]
    if type(scaling) == str:
        scaling = [scaling]

    for i in sampling:
        if i == 'random_under':
            X_train, y_train  = RandomUnderSampler(random_state=random_state).fit_resample(X_train, y_train)
        elif i == 'random_over':
            X_train, y_train  = RandomOverSampler(random_state=random_state).fit_resample(X_train, y_train)
        elif i == 'SMOTE':
            X_train, y_train = SMOTE(random_state=random_state).fit_resample(X_train, y_train)
        else:
            pass

    # scaling
    for j in scaling:
        if j == 'MaxAbsScaler':
            X_train = preprocessing.MaxAbsScaler().fit_transform(X_train)
        elif j == 'MinMaxScaler':
            X_train = preprocessing.MinMaxScaler().fit_transform(X_train)
        elif j == 'StandardScaler':
            X_train = preprocessing.StandardScaler().fit_transform(X_train)
        elif j == 'Normalizer':
            X_train = preprocessing.Normalizer().fit_transform(X_train)
        #elif j == 'MaxAbsScalerN':
        #    X_train_NMAS = preprocessing.MaxAbsScaler().fit_transform(X_train_NORM)
        #elif j == 'MinMaxScalerN':
        #    X_train_NMMS = preprocessing.MinMaxScaler().fit_transform(X_train_NORM)
        #elif j == 'StandardScalerN':
        #    X_train_NSS = preprocessing.StandardScaler().fit_transform(X_train_NORM)
        #elif j == 'NMaxAbsScaler':
        #    X_train_MASNORM = preprocessing.Normalizer().fit_transform(X_train_MAS)
        #elif j == 'NMinMaxScaler':
        #    X_train_MMSNORM = preprocessing.Normalizer().fit_transform(X_train_MMS)
        #elif j == 'NStandardScaler':
        #    X_train_SSNORM = preprocessing.Normalizer().fit_transform(X_train_SS)
        else:
            pass

    return X_train, y_train

# %% [markdown]
# # logistic regression

# %%
X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_fa)

# %% [markdown]
# #### lbfgs

# %%
start_time = time.time()
model_lbfgs = pd.DataFrame(find_model(X_train, y_train, X_val, y_val, algorithm='LogisticRegression', solver='lbfgs'))#.to_csv('da_lr_lbfgs.csv')
end_time = time.time()
duration_lbfgs = end_time-start_time
print(f"Operation took {duration_lbfgs} seconds.")
# Out:
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Operation took 180.9235451221466 seconds.

# %%
model_lbfgs.to_csv('fa_lr_lbfgs.csv')

# %%
model_lbfgs
# Out:
#               sampling                      scaling  train_accuracy  train_f1  \
# 22   RandomOverSampler                         none           0.672     0.676
# 20  RandomUnderSampler    MinMaxScaler + Normalizer           0.631     0.628
# 41         no_sampling    MaxAbsScaler + Normalizer           0.906     0.951
# 42         no_sampling    MinMaxScaler + Normalizer           0.906     0.951
# 19  RandomUnderSampler    MaxAbsScaler + Normalizer           0.611     0.610
# 43         no_sampling  StandardScaler + Normalizer           0.906     0.951
# 11  RandomUnderSampler                         none           0.703     0.706
# 31   RandomOverSampler    MinMaxScaler + Normalizer           0.628     0.635
# 30   RandomOverSampler    MaxAbsScaler + Normalizer           0.620     0.626
# 38         no_sampling    Normalizer + MaxAbsScaler           0.906     0.951
# 0                SMOTE                         none           0.689     0.688
# 37         no_sampling                   Normalizer           0.906     0.951
# 27   RandomOverSampler    Normalizer + MaxAbsScaler           0.636     0.639
# 35         no_sampling                 MinMaxScaler           0.906     0.951
# 21  RandomUnderSampler  StandardScaler + Normalizer           0.645     0.653
# 34         no_sampling                 MaxAbsScaler           0.906     0.951
# 26   RandomOverSampler                   Normalizer           0.593     0.599
# 28   RandomOverSampler    Normalizer + MinMaxScaler           0.638     0.639
# 15  RandomUnderSampler                   Normalizer           0.599     0.601
# 12  RandomUnderSampler                 MaxAbsScaler           0.638     0.644
# 13  RandomUnderSampler                 MinMaxScaler           0.650     0.655
# 33         no_sampling                         none           0.907     0.951
# 1                SMOTE                 MaxAbsScaler           0.654     0.650
# 16  RandomUnderSampler    Normalizer + MaxAbsScaler           0.638     0.641
# 7                SMOTE  Normalizer + StandardScaler           0.699     0.690
# 3                SMOTE               StandardScaler           0.687     0.684
# 18  RandomUnderSampler  Normalizer + StandardScaler           0.675     0.670
# 6                SMOTE    Normalizer + MinMaxScaler           0.675     0.664
# 9                SMOTE    MinMaxScaler + Normalizer           0.671     0.660
# 8                SMOTE    MaxAbsScaler + Normalizer           0.668     0.655
# 5                SMOTE    Normalizer + MaxAbsScaler           0.663     0.653
# 29   RandomOverSampler  Normalizer + StandardScaler           0.659     0.659
# 25   RandomOverSampler               StandardScaler           0.656     0.662
# 14  RandomUnderSampler               StandardScaler           0.643     0.647
# 17  RandomUnderSampler    Normalizer + MinMaxScaler           0.631     0.630
# 4                SMOTE                   Normalizer           0.606     0.600
# 40         no_sampling  Normalizer + StandardScaler           0.906     0.951
# 36         no_sampling               StandardScaler           0.905     0.950
# 10               SMOTE  StandardScaler + Normalizer           0.653     0.658
# 2                SMOTE                 MinMaxScaler           0.651     0.647
# 39         no_sampling    Normalizer + MinMaxScaler           0.906     0.951
# 23   RandomOverSampler                 MaxAbsScaler           0.646     0.652
# 24   RandomOverSampler                 MinMaxScaler           0.640     0.645
# 32   RandomOverSampler  StandardScaler + Normalizer           0.657     0.659
#
#     train_ba  train_mcc  val_accuracy  val_f1  val_ba  val_mcc
# 22     0.672      0.344         0.674   0.791   0.646    0.179
# 20     0.631      0.263         0.560   0.690   0.645    0.169
# 41     0.500      0.000         0.435   0.557   0.620    0.144
# 42     0.500      0.000         0.354   0.454   0.606    0.138
# 19     0.611      0.221         0.696   0.811   0.602    0.130
# 43     0.500      0.000         0.551   0.686   0.597    0.113
# 11     0.703      0.406         0.607   0.738   0.596    0.114
# 31     0.628      0.256         0.392   0.507   0.596    0.119
# 30     0.620      0.239         0.353   0.455   0.593    0.121
# 38     0.500      0.000         0.713   0.824   0.593    0.121
# 0      0.689      0.378         0.646   0.772   0.580    0.098
# 37     0.500      0.000         0.377   0.492   0.576    0.095
# 27     0.636      0.273         0.328   0.424   0.567    0.089
# 35     0.500      0.000         0.811   0.893   0.559    0.098
# 21     0.645      0.291         0.821   0.899   0.559    0.102
# 34     0.500      0.000         0.802   0.887   0.548    0.078
# 26     0.593      0.186         0.157   0.131   0.535    0.084
# 28     0.638      0.275         0.843   0.914   0.527    0.056
# 15     0.599      0.198         0.830   0.906   0.526    0.050
# 12     0.638      0.277         0.830   0.906   0.514    0.027
# 13     0.650      0.300         0.829   0.905   0.513    0.025
# 33     0.504      0.071         0.907   0.951   0.506    0.071
# 1      0.654      0.308         0.883   0.938   0.506    0.019
# 16     0.638      0.277         0.891   0.942   0.504    0.016
# 7      0.699      0.398         0.093   0.000   0.500    0.000
# 3      0.687      0.375         0.907   0.951   0.500    0.000
# 18     0.675      0.350         0.907   0.951   0.500    0.000
# 6      0.675      0.351         0.093   0.000   0.500    0.000
# 9      0.671      0.342         0.093   0.000   0.500    0.000
# 8      0.668      0.336         0.093   0.000   0.500    0.000
# 5      0.663      0.326         0.093   0.000   0.500    0.000
# 29     0.659      0.319         0.907   0.951   0.500    0.000
# 25     0.656      0.313         0.907   0.951   0.500    0.000
# 14     0.643      0.286         0.907   0.951   0.500    0.000
# 17     0.631      0.263         0.907   0.951   0.500    0.000
# 4      0.606      0.212         0.093   0.000   0.500    0.000
# 40     0.502      0.041         0.907   0.951   0.500    0.000
# 36     0.500     -0.009         0.907   0.951   0.500    0.000
# 10     0.653      0.306         0.904   0.950   0.499   -0.016
# 2      0.651      0.302         0.879   0.936   0.497   -0.008
# 39     0.500      0.000         0.900   0.947   0.496   -0.026
# 23     0.646      0.291         0.886   0.939   0.495   -0.020
# 24     0.640      0.281         0.883   0.938   0.493   -0.024
# 32     0.657      0.314         0.891   0.942   0.491   -0.040

# %%
model_lbfgs_melted = pd.melt(model_lbfgs, id_vars=['sampling', 'scaling'], value_vars=['train_accuracy', 'train_f1', 'train_ba', 'train_mcc', 'val_accuracy', 'val_f1', 'val_ba', 'val_mcc',], var_name='metrics', value_name='value')
model_lbfgs_melted = model_lbfgs_melted.drop(model_lbfgs_melted[model_lbfgs_melted['metrics'].isin(['train_accuracy', 'val_accuracy'])].index)
model_lbfgs_melted['set'] = np.where(model_lbfgs_melted['metrics'].str.startswith('train'), 'train', 'val')
model_lbfgs_melted['met'] = np.where(model_lbfgs_melted['metrics'].str.endswith('f1'), 'f1', 
                                     np.where(model_lbfgs_melted['metrics'].str.endswith('ba'), 'ba', 'mcc'))
model_lbfgs_melted['sampling'] = np.where(model_lbfgs_melted['sampling'].str.startswith('RandomOver'), 'Random Oversampler', 
                                          np.where(model_lbfgs_melted['sampling'].str.startswith('RandomUnder'), 'Random Undersampler', 
                                                   np.where(model_lbfgs_melted['sampling'].str.startswith('SMOTE'), 'SMOTE', 'No Sampling'
                                          )))
model_lbfgs_melted = model_lbfgs_melted.drop(columns=['metrics'])
model_lbfgs_melted
# Out:
#                 sampling                    scaling  value    set  met
# 44                 SMOTE                       none  0.716  train   f1
# 45    Random Oversampler                       none  0.692  train   f1
# 46   Random Undersampler                       none  0.729  train   f1
# 47                 SMOTE             StandardScaler  0.769  train   f1
# 48    Random Oversampler                 Normalizer  0.543  train   f1
# ..                   ...                        ...    ...    ...  ...
# 347  Random Undersampler  MinMaxScaler + Normalizer  0.000    val  mcc
# 348  Random Undersampler  MaxAbsScaler + Normalizer  0.000    val  mcc
# 349          No Sampling  MaxAbsScaler + Normalizer  0.000    val  mcc
# 350          No Sampling  MinMaxScaler + Normalizer  0.000    val  mcc
# 351          No Sampling                       none -0.016    val  mcc
#
# [264 rows x 5 columns]

# %%
sns.violinplot(data=model_lbfgs_melted[model_lbfgs_melted['met']=='mcc'], 
               x='sampling', y='value', hue='set',)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('MCC Values for Baseline Model, lbfgs solver')
plt.show()

# %%
sns.violinplot(data=model_lbfgs_melted[model_lbfgs_melted['met']=='ba'], 
               x='sampling', y='value', hue='set',)
plt.axhline(y=0.5, color='r', linestyle='--')
plt.title('BA Values for Baseline Model, lbfgs solver')
plt.show()

# %% [markdown]
# #### liblinear

# %%
start_time = time.time()
model_liblinear = pd.DataFrame(find_model(X_train, y_train, X_val, y_val, algorithm='LogisticRegression', solver='liblinear', multiclass = True,))
end_time = time.time()
duration_liblinear = end_time-start_time
print(f"Operation took {duration_liblinear} seconds.")
# Out:
# Operation took 20192.85226225853 seconds.

# %%
model_liblinear
# Out:
#               sampling                      scaling  train_accuracy  train_f1  \
# 84               SMOTE  Normalizer + StandardScaler           0.943     0.942
# 326  RandomOverSampler  Normalizer + StandardScaler           0.932     0.932
# 314  RandomOverSampler    Normalizer + MinMaxScaler           0.862     0.860
# 12               SMOTE                 MaxAbsScaler           0.896     0.894
# 266  RandomOverSampler                 MinMaxScaler           0.878     0.875
# ..                 ...                          ...             ...       ...
# 374        no_sampling                 MaxAbsScaler           0.864     0.842
# 345  RandomOverSampler    MinMaxScaler + Normalizer           0.756     0.753
# 264  RandomOverSampler                 MinMaxScaler           0.878     0.875
# 110              SMOTE  StandardScaler + Normalizer           0.860     0.858
# 253  RandomOverSampler                 MaxAbsScaler           0.880     0.878
#
#      train_ba  train_mcc                                           train_cf  \
# 84      0.943      0.924  [[2098, 150, 18, 0], [260, 1921, 56, 29], [0, ...
# 326     0.932      0.910  [[2036, 197, 33, 0], [275, 1892, 67, 32], [9, ...
# 314     0.862      0.817  [[1835, 303, 107, 21], [373, 1650, 119, 124], ...
# 12      0.896      0.862  [[1969, 225, 57, 15], [329, 1722, 100, 115], [...
# 266     0.878      0.837  [[1870, 287, 88, 21], [337, 1696, 106, 127], [...
# ..        ...        ...                                                ...
# 374     0.578      0.559  [[80, 202, 10, 0], [22, 2217, 25, 2], [10, 60,...
# 345     0.756      0.675  [[1553, 404, 212, 97], [382, 1429, 160, 295], ...
# 264     0.878      0.837  [[1870, 287, 88, 21], [337, 1696, 106, 127], [...
# 110     0.860      0.814  [[1853, 294, 92, 27], [365, 1621, 108, 172], [...
# 253     0.880      0.841  [[1874, 286, 81, 25], [347, 1684, 109, 126], [...
#
#      val_accuracy  val_f1  val_ba  val_mcc  \
# 84          0.812   0.829   0.808    0.588
# 326         0.805   0.824   0.795    0.579
# 314         0.745   0.775   0.794    0.527
# 12          0.754   0.784   0.787    0.529
# 266         0.749   0.779   0.785    0.520
# ..            ...     ...     ...      ...
# 374         0.079   0.088   0.246    0.017
# 345         0.187   0.192   0.244   -0.024
# 264         0.736   0.679   0.243   -0.029
# 110         0.057   0.044   0.243    0.006
# 253         0.321   0.379   0.241   -0.018
#
#                                                 val_cf
# 84   [[63, 25, 9, 0], [103, 620, 15, 17], [2, 2, 64...
# 326  [[66, 22, 9, 0], [107, 614, 17, 17], [4, 3, 61...
# 314  [[71, 17, 7, 2], [135, 551, 29, 40], [4, 1, 61...
# 12   [[68, 20, 5, 4], [130, 563, 19, 43], [3, 1, 62...
# 266  [[68, 21, 6, 2], [129, 559, 24, 43], [4, 1, 60...
# ..                                                 ...
# 374  [[1, 0, 6, 90], [17, 39, 123, 576], [0, 0, 9, ...
# 345  [[81, 16, 0, 0], [597, 96, 61, 1], [51, 16, 1,...
# 264  [[5, 92, 0, 0], [51, 696, 8, 0], [1, 67, 0, 0]...
# 110  [[0, 0, 7, 90], [9, 17, 127, 602], [0, 0, 11, ...
# 253  [[62, 35, 0, 0], [502, 244, 9, 0], [44, 24, 0,...
#
# [484 rows x 12 columns]

# %%
model_liblinear.to_csv('fb_lr_lbfgs.csv')
model_liblinear
# Out:
#               sampling                      scaling  train_accuracy  train_f1  \
# 84               SMOTE  Normalizer + StandardScaler           0.943     0.942
# 326  RandomOverSampler  Normalizer + StandardScaler           0.932     0.932
# 314  RandomOverSampler    Normalizer + MinMaxScaler           0.862     0.860
# 12               SMOTE                 MaxAbsScaler           0.896     0.894
# 266  RandomOverSampler                 MinMaxScaler           0.878     0.875
# ..                 ...                          ...             ...       ...
# 374        no_sampling                 MaxAbsScaler           0.864     0.842
# 345  RandomOverSampler    MinMaxScaler + Normalizer           0.756     0.753
# 264  RandomOverSampler                 MinMaxScaler           0.878     0.875
# 110              SMOTE  StandardScaler + Normalizer           0.860     0.858
# 253  RandomOverSampler                 MaxAbsScaler           0.880     0.878
#
#      train_ba  train_mcc                                           train_cf  \
# 84      0.943      0.924  [[2098, 150, 18, 0], [260, 1921, 56, 29], [0, ...
# 326     0.932      0.910  [[2036, 197, 33, 0], [275, 1892, 67, 32], [9, ...
# 314     0.862      0.817  [[1835, 303, 107, 21], [373, 1650, 119, 124], ...
# 12      0.896      0.862  [[1969, 225, 57, 15], [329, 1722, 100, 115], [...
# 266     0.878      0.837  [[1870, 287, 88, 21], [337, 1696, 106, 127], [...
# ..        ...        ...                                                ...
# 374     0.578      0.559  [[80, 202, 10, 0], [22, 2217, 25, 2], [10, 60,...
# 345     0.756      0.675  [[1553, 404, 212, 97], [382, 1429, 160, 295], ...
# 264     0.878      0.837  [[1870, 287, 88, 21], [337, 1696, 106, 127], [...
# 110     0.860      0.814  [[1853, 294, 92, 27], [365, 1621, 108, 172], [...
# 253     0.880      0.841  [[1874, 286, 81, 25], [347, 1684, 109, 126], [...
#
#      val_accuracy  val_f1  val_ba  val_mcc  \
# 84          0.812   0.829   0.808    0.588
# 326         0.805   0.824   0.795    0.579
# 314         0.745   0.775   0.794    0.527
# 12          0.754   0.784   0.787    0.529
# 266         0.749   0.779   0.785    0.520
# ..            ...     ...     ...      ...
# 374         0.079   0.088   0.246    0.017
# 345         0.187   0.192   0.244   -0.024
# 264         0.736   0.679   0.243   -0.029
# 110         0.057   0.044   0.243    0.006
# 253         0.321   0.379   0.241   -0.018
#
#                                                 val_cf
# 84   [[63, 25, 9, 0], [103, 620, 15, 17], [2, 2, 64...
# 326  [[66, 22, 9, 0], [107, 614, 17, 17], [4, 3, 61...
# 314  [[71, 17, 7, 2], [135, 551, 29, 40], [4, 1, 61...
# 12   [[68, 20, 5, 4], [130, 563, 19, 43], [3, 1, 62...
# 266  [[68, 21, 6, 2], [129, 559, 24, 43], [4, 1, 60...
# ..                                                 ...
# 374  [[1, 0, 6, 90], [17, 39, 123, 576], [0, 0, 9, ...
# 345  [[81, 16, 0, 0], [597, 96, 61, 1], [51, 16, 1,...
# 264  [[5, 92, 0, 0], [51, 696, 8, 0], [1, 67, 0, 0]...
# 110  [[0, 0, 7, 90], [9, 17, 127, 602], [0, 0, 11, ...
# 253  [[62, 35, 0, 0], [502, 244, 9, 0], [44, 24, 0,...
#
# [484 rows x 12 columns]

# %%
model_liblinear_melted = pd.melt(model_liblinear, id_vars=['sampling', 'scaling'], value_vars=['train_accuracy', 'train_f1', 'train_ba', 'train_mcc', 'val_accuracy', 'val_f1', 'val_ba', 'val_mcc',], var_name='metrics', value_name='value')
model_liblinear_melted = model_liblinear_melted.drop(model_liblinear_melted[model_liblinear_melted['metrics'].isin(['train_accuracy', 'val_accuracy'])].index)
model_liblinear_melted['set'] = np.where(model_liblinear_melted['metrics'].str.startswith('train'), 'train', 'val')
model_liblinear_melted['met'] = np.where(model_liblinear_melted['metrics'].str.endswith('f1'), 'f1', 
                                     np.where(model_liblinear_melted['metrics'].str.endswith('ba'), 'ba', 'mcc'))
model_liblinear_melted['sampling'] = np.where(model_liblinear_melted['sampling'].str.startswith('RandomOver'), 'Random Oversampler', 
                                          np.where(model_liblinear_melted['sampling'].str.startswith('RandomUnder'), 'Random Undersampler', 
                                                   np.where(model_liblinear_melted['sampling'].str.startswith('SMOTE'), 'SMOTE', 'No Sampling'
                                          )))
model_liblinear_melted = model_liblinear_melted.drop(columns=['metrics'])
model_liblinear_melted
# Out:
#                  sampling                      scaling  value    set  met
# 484           No Sampling    Normalizer + MaxAbsScaler  0.951  train   f1
# 485   Random Undersampler    Normalizer + MinMaxScaler  0.659  train   f1
# 486    Random Oversampler    Normalizer + MinMaxScaler  0.679  train   f1
# 487    Random Oversampler    Normalizer + MinMaxScaler  0.679  train   f1
# 488    Random Oversampler    MaxAbsScaler + Normalizer  0.649  train   f1
# ...                   ...                          ...    ...    ...  ...
# 3867   Random Oversampler               StandardScaler -0.112    val  mcc
# 3868                SMOTE                         none -0.009    val  mcc
# 3869   Random Oversampler               StandardScaler -0.015    val  mcc
# 3870   Random Oversampler  Normalizer + StandardScaler -0.023    val  mcc
# 3871          No Sampling                   Normalizer -0.049    val  mcc
#
# [2904 rows x 5 columns]

# %%
sns.violinplot(data=model_liblinear_melted[model_liblinear_melted['met']=='mcc'], 
               x='sampling', y='value', hue='set',)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('MCC Values for Baseline Model')
plt.show()

# %%
sns.violinplot(data=model_liblinear_melted[model_liblinear_melted['met']=='ba'], 
               x='sampling', y='value', hue='set',)
plt.axhline(y=0.5, color='r', linestyle='--')
plt.title('BA Values for Baseline Model')
plt.show()

# %% [markdown]
# #### saga

# %%
start_time = time.time()
model_saga = pd.DataFrame(find_model(X_train, y_train, X_val, y_val, algorithm='LogisticRegression', solver='saga'))#.to_csv('da_lr_saga.csv')
end_time = time.time()
duration_saga = end_time-start_time
print(f"Operation took {duration_saga} seconds.")
model_saga
# Out:
# Operation took 774.9750499725342 seconds.
#               sampling                      scaling  train_accuracy  train_f1  \
# 0                SMOTE                         none           0.625     0.628
# 22   RandomOverSampler                         none           0.613     0.624
# 11  RandomUnderSampler                         none           0.624     0.629
# 26   RandomOverSampler                   Normalizer           0.588     0.543
# 1                SMOTE                 MaxAbsScaler           0.731     0.725
# 2                SMOTE                 MinMaxScaler           0.734     0.727
# 23   RandomOverSampler                 MaxAbsScaler           0.701     0.700
# 24   RandomOverSampler                 MinMaxScaler           0.698     0.699
# 30   RandomOverSampler    MaxAbsScaler + Normalizer           0.650     0.649
# 37         no_sampling                   Normalizer           0.906     0.951
# 10               SMOTE  StandardScaler + Normalizer           0.728     0.730
# 15  RandomUnderSampler                   Normalizer           0.574     0.512
# 34         no_sampling                 MaxAbsScaler           0.907     0.951
# 36         no_sampling               StandardScaler           0.906     0.950
# 35         no_sampling                 MinMaxScaler           0.907     0.951
# 18  RandomUnderSampler  Normalizer + StandardScaler           0.758     0.753
# 16  RandomUnderSampler    Normalizer + MaxAbsScaler           0.673     0.664
# 32   RandomOverSampler  StandardScaler + Normalizer           0.692     0.698
# 43         no_sampling  StandardScaler + Normalizer           0.906     0.951
# 12  RandomUnderSampler                 MaxAbsScaler           0.696     0.692
# 13  RandomUnderSampler                 MinMaxScaler           0.689     0.687
# 38         no_sampling    Normalizer + MaxAbsScaler           0.906     0.951
# 28   RandomOverSampler    Normalizer + MinMaxScaler           0.688     0.679
# 25   RandomOverSampler               StandardScaler           0.747     0.743
# 21  RandomUnderSampler  StandardScaler + Normalizer           0.680     0.680
# 31   RandomOverSampler    MinMaxScaler + Normalizer           0.636     0.641
# 27   RandomOverSampler    Normalizer + MaxAbsScaler           0.689     0.678
# 17  RandomUnderSampler    Normalizer + MinMaxScaler           0.668     0.659
# 3                SMOTE               StandardScaler           0.768     0.760
# 4                SMOTE                   Normalizer           0.582     0.513
# 14  RandomUnderSampler               StandardScaler           0.737     0.732
# 5                SMOTE    Normalizer + MaxAbsScaler           0.696     0.683
# 6                SMOTE    Normalizer + MinMaxScaler           0.695     0.683
# 7                SMOTE  Normalizer + StandardScaler           0.757     0.743
# 29   RandomOverSampler  Normalizer + StandardScaler           0.743     0.730
# 8                SMOTE    MaxAbsScaler + Normalizer           0.680     0.674
# 9                SMOTE    MinMaxScaler + Normalizer           0.665     0.661
# 20  RandomUnderSampler    MinMaxScaler + Normalizer           0.613     0.596
# 19  RandomUnderSampler    MaxAbsScaler + Normalizer           0.606     0.598
# 40         no_sampling  Normalizer + StandardScaler           0.906     0.951
# 41         no_sampling    MaxAbsScaler + Normalizer           0.906     0.951
# 42         no_sampling    MinMaxScaler + Normalizer           0.906     0.951
# 33         no_sampling                         none           0.906     0.951
# 39         no_sampling    Normalizer + MinMaxScaler           0.906     0.951
#
#     train_ba  train_mcc                     train_cf  val_accuracy  val_f1  \
# 0      0.625      0.250   [[1294, 805], [769, 1330]]         0.624   0.753
# 22     0.613      0.227   [[1228, 871], [753, 1346]]         0.620   0.750
# 11     0.624      0.249       [[133, 84], [79, 138]]         0.587   0.721
# 26     0.588      0.179  [[1440, 659], [1072, 1027]]         0.477   0.616
# 1      0.731      0.463   [[1582, 517], [612, 1487]]         0.159   0.136
# 2      0.734      0.468   [[1591, 508], [609, 1490]]         0.155   0.128
# 23     0.701      0.403   [[1483, 616], [638, 1461]]         0.155   0.128
# 24     0.698      0.396   [[1460, 639], [629, 1470]]         0.154   0.126
# 30     0.650      0.300   [[1368, 731], [739, 1360]]         0.152   0.121
# 37     0.500      0.000        [[0, 217], [0, 2099]]         0.343   0.453
# 10     0.728      0.456   [[1513, 586], [556, 1543]]         0.149   0.116
# 15     0.574      0.152       [[152, 65], [120, 97]]         0.205   0.229
# 34     0.504      0.071        [[2, 215], [1, 2098]]         0.144   0.106
# 36     0.516      0.111        [[8, 209], [9, 2090]]         0.142   0.103
# 35     0.504      0.071        [[2, 215], [1, 2098]]         0.141   0.100
# 18     0.758      0.517       [[169, 48], [57, 160]]         0.140   0.098
# 16     0.673      0.346       [[152, 65], [77, 140]]         0.238   0.292
# 32     0.692      0.383   [[1405, 694], [601, 1498]]         0.136   0.090
# 43     0.500      0.000        [[0, 217], [0, 2099]]         0.133   0.085
# 12     0.696      0.392       [[154, 63], [69, 148]]         0.130   0.077
# 13     0.689      0.378       [[151, 66], [69, 148]]         0.127   0.072
# 38     0.500      0.000        [[0, 217], [0, 2099]]         0.903   0.949
# 28     0.688      0.378   [[1509, 590], [718, 1381]]         0.201   0.226
# 25     0.747      0.495   [[1603, 496], [564, 1535]]         0.142   0.108
# 21     0.680      0.359       [[147, 70], [69, 148]]         0.131   0.082
# 31     0.636      0.272   [[1304, 795], [733, 1366]]         0.119   0.056
# 27     0.689      0.379   [[1520, 579], [726, 1373]]         0.168   0.164
# 17     0.668      0.337       [[151, 66], [78, 139]]         0.843   0.914
# 3      0.768      0.537   [[1685, 414], [560, 1539]]         0.180   0.190
# 4      0.582      0.170   [[1517, 582], [1174, 925]]         0.097   0.009
# 14     0.737      0.475       [[164, 53], [61, 156]]         0.096   0.006
# 5      0.696      0.392   [[1542, 557], [721, 1378]]         0.096   0.006
# 6      0.695      0.391   [[1538, 561], [720, 1379]]         0.096   0.006
# 7      0.757      0.517   [[1700, 399], [622, 1477]]         0.093   0.000
# 29     0.743      0.488   [[1657, 442], [637, 1462]]         0.093   0.000
# 8      0.680      0.360   [[1469, 630], [713, 1386]]         0.093   0.000
# 9      0.665      0.331   [[1424, 675], [730, 1369]]         0.093   0.000
# 20     0.613      0.227       [[142, 75], [93, 124]]         0.093   0.000
# 19     0.606      0.212       [[136, 81], [90, 127]]         0.093   0.000
# 40     0.502      0.030        [[1, 216], [2, 2097]]         0.093   0.000
# 41     0.500      0.000        [[0, 217], [0, 2099]]         0.093   0.000
# 42     0.500      0.000        [[0, 217], [0, 2099]]         0.093   0.000
# 33     0.500     -0.007        [[0, 217], [1, 2098]]         0.907   0.951
# 39     0.500      0.000        [[0, 217], [0, 2099]]         0.905   0.950
#
#     val_ba  val_mcc                  val_cf
# 0    0.600    0.119  [[41, 31], [259, 441]]
# 22   0.591    0.109  [[40, 32], [261, 439]]
# 11   0.579    0.093  [[41, 31], [288, 412]]
# 26   0.537    0.043  [[44, 28], [376, 324]]
# 1    0.536    0.085    [[72, 0], [649, 51]]
# 2    0.534    0.083    [[72, 0], [652, 48]]
# 23   0.534    0.083    [[72, 0], [652, 48]]
# 24   0.534    0.082    [[72, 0], [653, 47]]
# 30   0.532    0.080    [[72, 0], [655, 45]]
# 37   0.532    0.041  [[55, 17], [490, 210]]
# 10   0.531    0.078    [[72, 0], [657, 43]]
# 15   0.530    0.053    [[67, 5], [609, 91]]
# 34   0.528    0.074    [[72, 0], [661, 39]]
# 36   0.527    0.073    [[72, 0], [662, 38]]
# 35   0.526    0.072    [[72, 0], [663, 37]]
# 18   0.526    0.071    [[72, 0], [664, 36]]
# 16   0.524    0.037   [[63, 9], [579, 121]]
# 32   0.524    0.068    [[72, 0], [667, 33]]
# 43   0.522    0.066    [[72, 0], [669, 31]]
# 12   0.520    0.062    [[72, 0], [672, 28]]
# 13   0.519    0.060    [[72, 0], [674, 26]]
# 38   0.517    0.090     [[3, 69], [6, 694]]
# 28   0.516    0.028    [[65, 7], [610, 90]]
# 25   0.515    0.038    [[70, 2], [660, 40]]
# 21   0.514    0.043    [[71, 1], [670, 30]]
# 31   0.514    0.052    [[72, 0], [680, 20]]
# 27   0.510    0.021    [[67, 5], [637, 63]]
# 17   0.509    0.018    [[7, 65], [56, 644]]
# 3    0.504    0.008    [[65, 7], [626, 74]]
# 4    0.502    0.020     [[72, 0], [697, 3]]
# 14   0.501    0.016     [[72, 0], [698, 2]]
# 5    0.501    0.016     [[72, 0], [698, 2]]
# 6    0.501    0.016     [[72, 0], [698, 2]]
# 7    0.500    0.000     [[72, 0], [700, 0]]
# 29   0.500    0.000     [[72, 0], [700, 0]]
# 8    0.500    0.000     [[72, 0], [700, 0]]
# 9    0.500    0.000     [[72, 0], [700, 0]]
# 20   0.500    0.000     [[72, 0], [700, 0]]
# 19   0.500    0.000     [[72, 0], [700, 0]]
# 40   0.500    0.000     [[72, 0], [700, 0]]
# 41   0.500    0.000     [[72, 0], [700, 0]]
# 42   0.500    0.000     [[72, 0], [700, 0]]
# 33   0.500    0.000     [[0, 72], [0, 700]]
# 39   0.499   -0.012     [[0, 72], [1, 699]]

# %%
model_saga.to_csv('fa_lr_saga.csv')

# %%
model_saga_melted = pd.melt(model_saga, id_vars=['sampling', 'scaling'], value_vars=['train_accuracy', 'train_f1', 'train_ba', 'train_mcc', 'val_accuracy', 'val_f1', 'val_ba', 'val_mcc',], var_name='metrics', value_name='value')
model_saga_melted = model_saga_melted.drop(model_saga_melted[model_saga_melted['metrics'].isin(['train_accuracy', 'val_accuracy'])].index)
model_saga_melted['set'] = np.where(model_saga_melted['metrics'].str.startswith('train'), 'train', 'val')
model_saga_melted['met'] = np.where(model_saga_melted['metrics'].str.endswith('f1'), 'f1', 
                                     np.where(model_saga_melted['metrics'].str.endswith('ba'), 'ba', 'mcc'))
model_saga_melted['sampling'] = np.where(model_saga_melted['sampling'].str.startswith('RandomOver'), 'Random Oversampler', 
                                          np.where(model_saga_melted['sampling'].str.startswith('RandomUnder'), 'Random Undersampler', 
                                                   np.where(model_saga_melted['sampling'].str.startswith('SMOTE'), 'SMOTE', 'No Sampling'
                                          )))
model_saga_melted = model_saga_melted.drop(columns=['metrics'])
model_saga_melted
# Out:
#                 sampling                      scaling  value    set  met
# 44                 SMOTE                         none  0.628  train   f1
# 45    Random Oversampler                         none  0.624  train   f1
# 46   Random Undersampler                         none  0.629  train   f1
# 47    Random Oversampler                   Normalizer  0.543  train   f1
# 48                 SMOTE                 MaxAbsScaler  0.725  train   f1
# ..                   ...                          ...    ...    ...  ...
# 347          No Sampling  Normalizer + StandardScaler  0.000    val  mcc
# 348          No Sampling    MaxAbsScaler + Normalizer  0.000    val  mcc
# 349          No Sampling    MinMaxScaler + Normalizer  0.000    val  mcc
# 350          No Sampling                         none  0.000    val  mcc
# 351          No Sampling    Normalizer + MinMaxScaler -0.012    val  mcc
#
# [264 rows x 5 columns]

# %%
sns.violinplot(data=model_saga_melted[model_saga_melted['met']=='mcc'], 
               x='sampling', y='value', hue='set',)
plt.title('MCC Values for Baseline Model, saga solver')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
sns.violinplot(data=model_saga_melted[model_saga_melted['met']=='ba'], 
               x='sampling', y='value', hue='set',)
plt.axhline(y=0.5, color='r', linestyle='--')
plt.title('BA Values for Baseline Model, saga solver')
plt.show()

# %% [markdown]
# #### plot for all solvers

# %%
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(12, 6), sharex=True, sharey=True)

ax[0, 0].set_title(f'lbfgs, t = {round(duration_lbfgs, 2)} s')
ax[0, 1].set_title(f'liblinear, t = {round(duration_liblinear, 2)} s')
ax[0, 2].set_title(f'saga, t = {round(duration_saga, 2)} s')

for i, j in enumerate([model_lbfgs_melted, model_liblinear_melted, model_saga_melted]):
    sns.violinplot(data=j[j['met']=='mcc'].sort_values(['sampling', 'set']), x='sampling', y='value', hue='set', ax=ax[0, i])
    sns.violinplot(data=j[j['met']=='ba']‚ x='sampling', y='value', hue='set', ax=ax[1, i])
    ax[0, i].axhline(y=0, color='r', linestyle='--')
    ax[1, i].axhline(y=0.5, color='r', linestyle='--')
    ax[1, i].set_xticklabels(ax[1, i].get_xticklabels(), rotation=90, ha='center')
    ax[0, i].set_xlabel('')
    ax[1, i].set_xlabel('')
    ax[0, i].set_ylabel('')
    ax[1, i].set_ylabel('')
    ax[0, 0].set_ylabel('Matthews Correlation\nCoefficient')
    ax[1, 0].set_ylabel('Balanced Accuracy')
plt.setp(ax,
         yticks=[-0.2, 0, 0.2, 0.4, 0.6, 0.8, 1],
         xticklabels=['No\nSampling',  'Random\nOversampling', 'Random\nUndersampling', 'SMOTE'],
)
plt.show()

# %%
model_liblinear
# Out:
#               sampling                      scaling  train_accuracy  train_f1  \
# 22   RandomOverSampler                         none           0.672     0.676
# 20  RandomUnderSampler    MinMaxScaler + Normalizer           0.631     0.628
# 19  RandomUnderSampler    MaxAbsScaler + Normalizer           0.611     0.610
# 43         no_sampling  StandardScaler + Normalizer           0.906     0.951
# 11  RandomUnderSampler                         none           0.700     0.703
# 30   RandomOverSampler    MaxAbsScaler + Normalizer           0.620     0.627
# 31   RandomOverSampler    MinMaxScaler + Normalizer           0.628     0.634
# 0                SMOTE                         none           0.688     0.686
# 15  RandomUnderSampler                   Normalizer           0.599     0.601
# 26   RandomOverSampler                   Normalizer           0.593     0.599
# 21  RandomUnderSampler  StandardScaler + Normalizer           0.645     0.653
# 5                SMOTE    Normalizer + MaxAbsScaler           0.657     0.650
# 12  RandomUnderSampler                 MaxAbsScaler           0.638     0.644
# 13  RandomUnderSampler                 MinMaxScaler           0.650     0.655
# 41         no_sampling    MaxAbsScaler + Normalizer           0.906     0.951
# 35         no_sampling                 MinMaxScaler           0.906     0.951
# 28   RandomOverSampler    Normalizer + MinMaxScaler           0.638     0.639
# 42         no_sampling    MinMaxScaler + Normalizer           0.906     0.951
# 33         no_sampling                         none           0.907     0.951
# 34         no_sampling                 MaxAbsScaler           0.906     0.951
# 2                SMOTE                 MinMaxScaler           0.649     0.646
# 16  RandomUnderSampler    Normalizer + MaxAbsScaler           0.636     0.638
# 9                SMOTE    MinMaxScaler + Normalizer           0.665     0.656
# 4                SMOTE                   Normalizer           0.604     0.597
# 7                SMOTE  Normalizer + StandardScaler           0.698     0.689
# 3                SMOTE               StandardScaler           0.688     0.684
# 18  RandomUnderSampler  Normalizer + StandardScaler           0.675     0.670
# 6                SMOTE    Normalizer + MinMaxScaler           0.670     0.661
# 8                SMOTE    MaxAbsScaler + Normalizer           0.664     0.654
# 29   RandomOverSampler  Normalizer + StandardScaler           0.659     0.659
# 25   RandomOverSampler               StandardScaler           0.656     0.662
# 14  RandomUnderSampler               StandardScaler           0.643     0.647
# 27   RandomOverSampler    Normalizer + MaxAbsScaler           0.635     0.638
# 17  RandomUnderSampler    Normalizer + MinMaxScaler           0.631     0.630
# 40         no_sampling  Normalizer + StandardScaler           0.906     0.951
# 37         no_sampling                   Normalizer           0.906     0.951
# 38         no_sampling    Normalizer + MaxAbsScaler           0.906     0.951
# 39         no_sampling    Normalizer + MinMaxScaler           0.906     0.951
# 36         no_sampling               StandardScaler           0.905     0.950
# 10               SMOTE  StandardScaler + Normalizer           0.653     0.658
# 24   RandomOverSampler                 MinMaxScaler           0.638     0.645
# 23   RandomOverSampler                 MaxAbsScaler           0.646     0.653
# 32   RandomOverSampler  StandardScaler + Normalizer           0.657     0.659
# 1                SMOTE                 MaxAbsScaler           0.655     0.651
#
#     train_ba  train_mcc  val_accuracy  val_f1  val_ba  val_mcc
# 22     0.672      0.344         0.672   0.789   0.645    0.177
# 20     0.631      0.263         0.564   0.696   0.629    0.150
# 19     0.611      0.221         0.560   0.693   0.620    0.140
# 43     0.500      0.000         0.555   0.690   0.599    0.115
# 11     0.700      0.401         0.604   0.735   0.595    0.112
# 30     0.620      0.240         0.516   0.652   0.590    0.105
# 31     0.628      0.256         0.525   0.662   0.582    0.096
# 0      0.688      0.375         0.647   0.773   0.581    0.099
# 15     0.599      0.198         0.722   0.831   0.579    0.105
# 26     0.593      0.185         0.309   0.395   0.569    0.094
# 21     0.645      0.291         0.821   0.899   0.559    0.102
# 5      0.657      0.313         0.187   0.193   0.533    0.063
# 12     0.638      0.277         0.829   0.905   0.513    0.025
# 13     0.650      0.300         0.827   0.904   0.512    0.024
# 41     0.500      0.000         0.894   0.944   0.512    0.047
# 35     0.500      0.000         0.847   0.916   0.511    0.023
# 28     0.638      0.276         0.852   0.919   0.507    0.017
# 42     0.500      0.000         0.874   0.932   0.507    0.020
# 33     0.504      0.071         0.907   0.951   0.506    0.071
# 34     0.500      0.000         0.870   0.930   0.505    0.013
# 2      0.649      0.299         0.881   0.936   0.504    0.014
# 16     0.636      0.272         0.843   0.914   0.502    0.005
# 9      0.665      0.330         0.095   0.003   0.501    0.012
# 4      0.604      0.208         0.095   0.003   0.501    0.012
# 7      0.698      0.397         0.093   0.000   0.500    0.000
# 3      0.688      0.375         0.907   0.951   0.500    0.000
# 18     0.675      0.350         0.907   0.951   0.500    0.000
# 6      0.670      0.341         0.093   0.000   0.500    0.000
# 8      0.664      0.328         0.093   0.000   0.500    0.000
# 29     0.659      0.319         0.907   0.951   0.500    0.000
# 25     0.656      0.313         0.907   0.951   0.500    0.000
# 14     0.643      0.286         0.907   0.951   0.500    0.000
# 27     0.635      0.271         0.907   0.951   0.500    0.000
# 17     0.631      0.263         0.907   0.951   0.500    0.000
# 40     0.502      0.041         0.907   0.951   0.500    0.000
# 37     0.500      0.000         0.907   0.951   0.500    0.000
# 38     0.500      0.000         0.907   0.951   0.500    0.000
# 39     0.500      0.000         0.907   0.951   0.500    0.000
# 36     0.500     -0.009         0.907   0.951   0.500    0.000
# 10     0.653      0.305         0.904   0.950   0.499   -0.016
# 24     0.638      0.277         0.882   0.937   0.493   -0.026
# 23     0.646      0.293         0.892   0.943   0.492   -0.039
# 32     0.657      0.314         0.891   0.942   0.491   -0.040
# 1      0.655      0.310         0.883   0.938   0.487   -0.050

# %% [markdown]
# ## feature importance

# %%
solver='liblinear'
max_iter=10000
random_state=0

X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_fa)

X_train, y_train  = RandomUnderSampler(random_state=random_state).fit_resample(X_train, y_train)

scaler = preprocessing.Normalizer()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

scaler = preprocessing.MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)


# create final model in linreg
lr = LogisticRegression(solver=solver,max_iter=max_iter, random_state=random_state)
fit = lr.fit(X_train, y_train)
y_pred = fit.predict(X_train)
y_val_pred = fit.predict(X_val)

# calculate statistical metrics for training set
train_f1 = metrics.f1_score(y_train, y_pred, average = 'binary')
train_ba = metrics.balanced_accuracy_score(y_train, y_pred)
train_mcc = metrics.matthews_corrcoef(y_train, y_pred)
train_cf = metrics.confusion_matrix(y_train, y_pred)

# calculate statistical metrics for val set
val_f1 = metrics.f1_score(y_val, y_val_pred, average = 'binary')
val_ba = metrics.balanced_accuracy_score(y_val, y_val_pred)
val_mcc = metrics.matthews_corrcoef(y_val, y_val_pred)
val_cf = metrics.confusion_matrix(y_val, y_val_pred)

print(f'train scores \n')
print(f'f1: {train_f1:.3f}')
print(f'balanced accuracy: {train_ba:.3f}')
print(f'matthews corrcoeff: {train_mcc:.3f}')
print(f'cf:\n{train_cf}')
print('')
print(f'val scores \n')
print(f'f1: {val_f1:.3f}')
print(f'balanced accuracy: {val_ba:.3f}')
print(f'matthews corrcoeff: {val_mcc:.3f}')
print(f'cf:\n{val_cf}')
# Out:
# train scores
#
# f1: 0.659
# balanced accuracy: 0.668
# matthews corrcoeff: 0.337
# cf:
# [[151  66]
#  [ 78 139]]
#
# val scores
#
# f1: 0.715
# balanced accuracy: 0.614
# matthews corrcoeff: 0.134
# cf:
# [[ 47  25]
#  [297 403]]

# %%
result = permutation_importance(fit, X_val, y_val, n_repeats=10, random_state=random_state)

feature_importance = pd.DataFrame({'Feature': descnm,
                                   'Importance': result.importances_mean,
                                   'Standard Deviation': result.importances_std})
feature_importance = feature_importance.sort_values('Importance', ascending=True)


ax = feature_importance.plot(x='Feature', y='Importance', kind='barh', 
                             
                            yerr='Standard Deviation', capsize=4)
ax.set_xlabel('Permutation Importance')
ax.set_title('Permutation Importance with Standard Deviation')
plt.tight_layout
plt.show()

# %%
feature_importance[feature_importance['Importance'] > 0].Feature.to_list()
# Out:
# ['fr_NH2',
#  'NHOHCount',
#  'fr_priamide',
#  'PEOE_VSA1',
#  'NumSaturatedHeterocycles',
#  'fr_Ndealkylation1',
#  'VSA_EState7',
#  'fr_piperzine',
#  'SMR_VSA4',
#  'PEOE_VSA14',
#  'SlogP_VSA3',
#  'SlogP_VSA11',
#  'SlogP_VSA8',
#  'EState_VSA8',
#  'SMR_VSA6',
#  'SMR_VSA9',
#  'PEOE_VSA8',
#  'EState_VSA6',
#  'PEOE_VSA11',
#  'EState_VSA4',
#  'SlogP_VSA2',
#  'EState_VSA5']

# %% [markdown]
# ### retrain

# %%
solver='liblinear'
max_iter=10000
random_state=0

X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_da[features_])

X_train, y_train  = RandomUnderSampler(random_state=random_state).fit_resample(X_train, y_train)
X_train = preprocessing.MinMaxScaler().fit_transform(X_train)
X_train = preprocessing.Normalizer().fit_transform(X_train)

# create final model in linreg
lr = LogisticRegression(solver=solver,max_iter=max_iter, random_state=random_state)
fit = lr.fit(X_train, y_train)
y_pred = fit.predict(X_train)
y_val_pred = fit.predict(X_val)

# calculate statistical metrics for training set
train_f1 = metrics.f1_score(y_train, y_pred, average = 'binary')
train_ba = metrics.balanced_accuracy_score(y_train, y_pred)
train_mcc = metrics.matthews_corrcoef(y_train, y_pred)
train_cf = metrics.confusion_matrix(y_train, y_pred)

# calculate statistical metrics for val set
val_f1 = metrics.f1_score(y_val, y_val_pred, average = 'binary')
val_ba = metrics.balanced_accuracy_score(y_val, y_val_pred)
val_mcc = metrics.matthews_corrcoef(y_val, y_val_pred)
val_cf = metrics.confusion_matrix(y_val, y_val_pred)

print(f'train scores \n')
print(f'f1: {train_f1:.3f}')
print(f'balanced accuracy: {train_ba:.3f}')
print(f'matthews corrcoeff: {train_mcc:.3f}')
print(f'cf:\n{train_cf}')
print('')
print(f'val scores \n')
print(f'f1: {val_f1:.3f}')
print(f'balanced accuracy: {val_ba:.3f}')
print(f'matthews corrcoeff: {val_mcc:.3f}')
print(f'cf:\n{val_cf}')
# Out:
# train scores
#
# f1: 0.593
# balanced accuracy: 0.604
# matthews corrcoeff: 0.209
# cf:
# [[127  74]
#  [ 85 116]]
#
# val scores
#
# f1: 0.159
# balanced accuracy: 0.521
# matthews corrcoeff: 0.047
# cf:
# [[ 64   3]
#  [505  48]]

# %% [markdown]
# ## hyperparameter tuning using gridsearch

# %%
X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_fb)

# %%
def grid_search(X_train, y_train,
                param_grid,
                algorithm = 'LogisticRegression',
                fold = 3,
                scoring='balanced_accuracy',
                random_state=0,
                ):
    
    if algorithm == 'LogisticRegression':
        model = LogisticRegression(random_state=random_state)
    elif algorithm == 'SVC':
        model = SVC(random_state=random_state)
    elif algorithm == 'RandomForestClassifier':
        model = RandomForestClassifier(random_state=random_state)
    else:
        pass

    cv_ = model_selection.GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        cv=fold,
        verbose=3,
        scoring=scoring,
        )
    cv_.fit(X_train, y_train)

    return cv_.cv_results_, cv_.best_params_

# %%
param_grid = {
    'solver': ['liblinear', 'lbfgs', 'saga',],# 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
    'penalty': ['l1', 'l2', 'elasticnet', None],
    'class_weight':[None, 'balanced'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'multi_class': ['auto', 'ovr', 'multinomial'],
    'max_iter': [10000],
    'random_state':[0]
}

random_state=0

X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_fb)
X_train, y_train  = SMOTE(random_state=random_state).fit_resample(X_train, y_train)
scaler = preprocessing.Normalizer()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

cv_res, cv_params = grid_search(X_val, y_val, param_grid, 
                                algorithm='LogisticRegression',)

cv_params
# Out:
# Fitting 3 folds for each of 504 candidates, totalling 1512 fits
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.2s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.639 total time=   0.4s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.617 total time=   0.5s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.640 total time=   0.5s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.290 total time=   0.4s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.291 total time=   0.5s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.380 total time=   0.4s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.296 total time=  36.3s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.291 total time= 4.3min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.380 total time= 3.4min
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=lbfgs;, score=0.579 total time=   0.7s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=lbfgs;, score=0.547 total time=   3.1s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=lbfgs;, score=0.666 total time=   3.8s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=saga;, score=0.580 total time= 1.5min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=saga;, score=0.580 total time= 1.3min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=saga;, score=0.648 total time= 1.4min
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.2s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.3s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.4s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=liblinear;, score=0.639 total time=   0.7s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=liblinear;, score=0.617 total time=   0.5s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=liblinear;, score=0.640 total time=   0.5s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=lbfgs;, score=0.287 total time=   1.8s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=lbfgs;, score=0.270 total time=   0.5s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=lbfgs;, score=0.327 total time=   0.3s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=saga;, score=0.287 total time= 1.0min
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=saga;, score=0.291 total time=  58.7s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=saga;, score=0.334 total time=  35.3s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=lbfgs;, score=0.503 total time=   1.1s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=lbfgs;, score=0.535 total time=  18.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=lbfgs;, score=0.656 total time=   7.3s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=saga;, score=0.598 total time= 2.8min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=saga;, score=0.459 total time= 3.6min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=saga;, score=0.666 total time= 4.5min
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.2s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=lbfgs;, score=0.290 total time=   0.5s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=lbfgs;, score=0.291 total time=   0.6s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=lbfgs;, score=0.380 total time=   0.5s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=saga;, score=0.296 total time=  51.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=saga;, score=0.291 total time= 4.8min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=saga;, score=0.380 total time= 4.6min
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.2s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.579 total time=   0.7s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.547 total time=   2.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.666 total time=   4.1s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.580 total time= 2.7min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.580 total time= 2.5min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=None, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.648 total time= 2.5min
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.2s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.2s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.3s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.2s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.696 total time=   0.9s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.650 total time=   0.9s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.603 total time=   0.8s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.683 total time=   1.1s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.637 total time=   3.2s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.643 total time=   0.8s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.687 total time=   7.7s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.645 total time=  14.1s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.637 total time= 7.3min
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=lbfgs;, score=0.533 total time=   3.1s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=lbfgs;, score=0.531 total time=   5.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=lbfgs;, score=0.660 total time=   4.5s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=saga;, score=0.719 total time= 2.6min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=saga;, score=0.647 total time= 2.8min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=auto, penalty=None, random_state=0, solver=saga;, score=0.681 total time= 2.3min
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.2s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.2s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=liblinear;, score=0.696 total time=   0.5s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=liblinear;, score=0.650 total time=   0.5s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=liblinear;, score=0.603 total time=   0.5s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=lbfgs;, score=0.667 total time=   0.5s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=lbfgs;, score=0.581 total time=   0.4s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=lbfgs;, score=0.629 total time=   0.4s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=saga;, score=0.656 total time=  32.5s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=saga;, score=0.580 total time=  30.2s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=l2, random_state=0, solver=saga;, score=0.627 total time= 4.5min
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=lbfgs;, score=0.443 total time=   1.8s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=lbfgs;, score=0.516 total time=  20.6s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=lbfgs;, score=0.560 total time=  10.8s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=saga;, score=0.680 total time= 5.2min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=saga;, score=0.686 total time= 4.1min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=ovr, penalty=None, random_state=0, solver=saga;, score=0.658 total time= 3.2min
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.1s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.2s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=lbfgs;, score=0.683 total time=   0.3s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=lbfgs;, score=0.637 total time=   0.3s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=lbfgs;, score=0.643 total time=   0.3s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=saga;, score=0.687 total time=   5.4s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=saga;, score=0.645 total time=   9.1s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=l2, random_state=0, solver=saga;, score=0.637 total time= 3.7min
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.533 total time=   0.8s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.531 total time=   3.1s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.660 total time=   1.9s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.719 total time= 1.8min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.647 total time= 1.7min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=0.001, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.681 total time= 1.5min
# [CV 1/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 2/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 3/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=liblinear;, score=0.250 total time=   0.1s
# [CV 1/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time= 1.1min
# [CV 2/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=  31.2s
# [CV 3/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l1, random_state=0, solver=saga;, score=0.250 total time=  16.4s
# [CV 1/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.655 total time=   0.7s
# [CV 2/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.587 total time=   0.5s
# [CV 3/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=liblinear;, score=0.658 total time=   1.1s
# [CV 1/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.501 total time=   0.6s
# [CV 2/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.409 total time=   0.6s
# [CV 3/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=lbfgs;, score=0.586 total time=   0.5s
# [CV 1/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.568 total time=  40.1s
# [CV 2/3] END C=0.01, class_weight=None, max_iter=10000, multi_class=auto, penalty=l2, random_state=0, solver=saga;, score=0.409 total time=  50.9s
# ...
# [CV 3/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 2/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 3/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=elasticnet, random_state=0, solver=saga;, score=nan total time=   0.0s
# [CV 1/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=liblinear;, score=nan total time=   0.0s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.533 total time=   0.5s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.531 total time=   1.4s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=lbfgs;, score=0.660 total time=   2.3s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 1/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.719 total time= 1.0min
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 2/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.647 total time=  55.5s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# [CV 3/3] END C=1000, class_weight=balanced, max_iter=10000, multi_class=multinomial, penalty=None, random_state=0, solver=saga;, score=0.681 total time=  59.2s
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 714 fits failed out of a total of 1512.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 126 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 126 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 66, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 126 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 126 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1179, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 84 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1228, in fit
#     self.coef_, self.intercept_, self.n_iter_ = _fit_liblinear(
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/svm/_base.py", line 1229, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/svm/_base.py", line 1060, in _get_liblinear_solver_type
#     raise ValueError(
# ValueError: Unsupported set of arguments: The combination of penalty='None' and loss='logistic_regression' is not supported, Parameters: penalty=None, loss='logistic_regression', dual=False
#
# --------------------------------------------------------------------------------
# 126 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1219, in fit
#     multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#   File "/opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 92, in _check_multi_class
#     raise ValueError("Solver %s does not support a multinomial backend." % solver)
# ValueError: Solver liblinear does not support a multinomial backend.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/envs/kinase/lib/python3.10/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.25              nan 0.25       0.6322981  0.32019728 0.32247076
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.25              nan 0.25       0.6322981  0.29458581 0.30435743
#         nan        nan        nan        nan 0.56462057 0.57437997
#         nan        nan 0.25              nan 0.32019728 0.32247076
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.25              nan 0.25       0.64971045 0.65461378 0.65641264
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.25              nan 0.25       0.64971045 0.62591322 0.62105989
#         nan        nan        nan        nan 0.50635835 0.67475043
#         nan        nan 0.25              nan 0.65461378 0.65641264
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.25              nan 0.25       0.63342821 0.49907639 0.52114359
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.25              nan 0.25       0.63342821 0.46225798 0.51152312
#         nan        nan        nan        nan 0.56462057 0.57437997
#         nan        nan 0.25              nan 0.49907639 0.52114359
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.31947577        nan 0.45527836 0.68636806 0.65392141 0.68489839
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.31947577        nan 0.50191776 0.68636806 0.64772067 0.65534903
#         nan        nan        nan        nan 0.50635835 0.67475043
#         nan        nan 0.45527836        nan 0.65392141 0.68489839
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.40878578        nan 0.36905291 0.61356376 0.56032314 0.61179233
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.40878578        nan 0.3647535  0.61356376 0.52978554 0.59104252
#         nan        nan        nan        nan 0.56462057 0.57437997
#         nan        nan 0.36905291        nan 0.56032314 0.61179233
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.60754181        nan 0.61598231 0.65511782 0.65066938 0.68401827
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.60754181        nan 0.62042945 0.65511782 0.64888921 0.69828062
#         nan        nan        nan        nan 0.50635835 0.67475043
#         nan        nan 0.61598231        nan 0.65066938 0.68401827
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.56569211        nan 0.57373279 0.59707325 0.56560135 0.61232134
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.56569211        nan 0.57753364 0.59707325 0.55294964 0.56889554
#         nan        nan        nan        nan 0.56462057 0.57437997
#         nan        nan 0.57373279        nan 0.56560135 0.61232134
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.61666805        nan 0.66460315 0.64121852 0.61140943 0.68894066
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.61666805        nan 0.66901495 0.64121852 0.64370244 0.67569588
#         nan        nan        nan        nan 0.50635835 0.67475043
#         nan        nan 0.66460315        nan 0.61140943 0.68894066
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.56109329        nan 0.60356055 0.58439061 0.56592168 0.60273054
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.56109329        nan 0.57108879 0.58439061 0.56394762 0.57075678
#         nan        nan        nan        nan 0.56462057 0.57437997
#         nan        nan 0.60356055        nan 0.56592168 0.60273054
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.59976186        nan 0.68792428 0.6108925  0.61535731 0.68219229
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.59976186        nan 0.6766919  0.6108925  0.59919948 0.67408641
#         nan        nan        nan        nan 0.50635835 0.67475043
#         nan        nan 0.68792428        nan 0.61535731 0.68219229
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.56101015        nan 0.60273054 0.58331409 0.56906434 0.60273054
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.56101015        nan 0.57437997 0.58331409 0.57017498 0.57437997
#         nan        nan        nan        nan 0.56462057 0.57437997
#         nan        nan 0.60273054        nan 0.56906434 0.60273054
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.59105659        nan 0.6828563  0.58919244 0.58992132 0.68219229
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.59105659        nan 0.67702259 0.58919244 0.58587823 0.67441842
#         nan        nan        nan        nan 0.50635835 0.67475043
#         nan        nan 0.6828563         nan 0.58992132 0.68219229
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.5606368         nan 0.60273054 0.58066859 0.57478016 0.60273054
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.5606368         nan 0.57437997 0.58066859 0.55370071 0.57437997
#         nan        nan        nan        nan 0.56462057 0.57437997
#         nan        nan 0.60273054        nan 0.57478016 0.60273054
#         nan        nan        nan        nan 0.59713702 0.60273054
#  0.56816991        nan 0.68252429 0.59179792 0.58839472 0.68252429
#         nan        nan        nan        nan 0.57467629 0.68252429
#  0.56816991        nan 0.67475043 0.59179792 0.58024394 0.67475043
#         nan        nan        nan        nan 0.50635835 0.67475043
#         nan        nan 0.68252429        nan 0.58839472 0.68252429
#         nan        nan        nan        nan 0.57467629 0.68252429]
#   warnings.warn(
# {'C': 0.1,
#  'class_weight': 'balanced',
#  'max_iter': 10000,
#  'multi_class': 'ovr',
#  'penalty': 'l2',
#  'random_state': 0,
#  'solver': 'saga'}

# %%
fb_lr_cv_iter_1 = pd.DataFrame(cv_res).sort_values(by='mean_test_score', ascending=False)
fb_lr_cv_iter_1.to_csv('fb_lr_cv_iter_1.csv', index=False)
fb_lr_cv_iter_1
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 197      98.826433     34.690506         0.003683        0.000981     0.1
# 257      46.847122      4.323234         0.002437        0.000011       1
# 281      47.079557      4.014273         0.002476        0.000057       1
# 326      89.820651      4.381865         0.002899        0.000636      10
# 350      88.273610      3.486321         0.002453        0.000025      10
# ..             ...           ...              ...             ...     ...
# 495       0.005145      0.000148         0.000000        0.000000    1000
# 498       0.004225      0.000136         0.000000        0.000000    1000
# 499       0.003960      0.000270         0.000000        0.000000    1000
# 500       0.004282      0.000631         0.000000        0.000000    1000
# 501       0.005648      0.000310         0.000000        0.000000    1000
#
#     param_class_weight param_max_iter param_multi_class param_penalty  \
# 197           balanced          10000               ovr            l2
# 257           balanced          10000              auto            l2
# 281           balanced          10000       multinomial            l2
# 326           balanced          10000              auto            l1
# 350           balanced          10000       multinomial            l1
# ..                 ...            ...               ...           ...
# 495           balanced          10000       multinomial            l2
# 498           balanced          10000       multinomial    elasticnet
# 499           balanced          10000       multinomial    elasticnet
# 500           balanced          10000       multinomial    elasticnet
# 501           balanced          10000       multinomial          None
#
#     param_random_state param_solver  \
# 197                  0         saga
# 257                  0         saga
# 281                  0         saga
# 326                  0         saga
# 350                  0         saga
# ..                 ...          ...
# 495                  0    liblinear
# 498                  0    liblinear
# 499                  0        lbfgs
# 500                  0         saga
# 501                  0    liblinear
#
#                                                 params  split0_test_score  \
# 197  {'C': 0.1, 'class_weight': 'balanced', 'max_it...           0.722661
# 257  {'C': 1, 'class_weight': 'balanced', 'max_iter...           0.718979
# 281  {'C': 1, 'class_weight': 'balanced', 'max_iter...           0.718979
# 326  {'C': 10, 'class_weight': 'balanced', 'max_ite...           0.723815
# 350  {'C': 10, 'class_weight': 'balanced', 'max_ite...           0.723815
# ..                                                 ...                ...
# 495  {'C': 1000, 'class_weight': 'balanced', 'max_i...                NaN
# 498  {'C': 1000, 'class_weight': 'balanced', 'max_i...                NaN
# 499  {'C': 1000, 'class_weight': 'balanced', 'max_i...                NaN
# 500  {'C': 1000, 'class_weight': 'balanced', 'max_i...                NaN
# 501  {'C': 1000, 'class_weight': 'balanced', 'max_i...                NaN
#
#      split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 197           0.693909           0.678272         0.698281        0.018384
# 257           0.657212           0.690631         0.688941        0.025245
# 281           0.657212           0.690631         0.688941        0.025245
# 326           0.647334           0.692623         0.687924        0.031400
# 350           0.647334           0.692623         0.687924        0.031400
# ..                 ...                ...              ...             ...
# 495                NaN                NaN              NaN             NaN
# 498                NaN                NaN              NaN             NaN
# 499                NaN                NaN              NaN             NaN
# 500                NaN                NaN              NaN             NaN
# 501                NaN                NaN              NaN             NaN
#
#      rank_test_score
# 197                1
# 257                2
# 281                2
# 326                4
# 350                4
# ..               ...
# 495              267
# 498              267
# 499              267
# 500              267
# 501              267
#
# [504 rows x 18 columns]

# %% [markdown]
# ## test

# %%
solver='saga'
max_iter=10000
random_state=0
C=0.1
penalty='l2'
class_weight=None
multi_class='ovr'

X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_fb)

X_train, y_train  = SMOTE(random_state=random_state).fit_resample(X_train, y_train)
print('finished sampling')
scaler = preprocessing.Normalizer()
X_train = scaler.fit_transform(X_train)
print('finished normalizing train')
X_val = scaler.transform(X_val)
print('finished normalizing val')
X_test = scaler.transform(X_test)
print('finished normalizing test')
scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
print('finished scaling train')
X_val = scaler.transform(X_val)
print('finished scaling validation')
X_test = scaler.transform(X_test)
print('finished scaling test')

# create final model in linreg
lr = LogisticRegression(solver=solver,max_iter=max_iter, random_state=random_state, C=C, penalty=penalty, class_weight=class_weight, multi_class=multi_class)
fit = lr.fit(X_train, y_train)
print('finished fitting')
y_pred = fit.predict(X_train)
print('finished predicting train')
y_val_pred = fit.predict(X_val)
print('finished predicting val')
y_test_pred = fit.predict(X_test)
print('finished predicting test')

# calculate statistical metrics for training set
train_f1 = metrics.f1_score(y_train, y_pred, average = 'weighted')
train_ba = metrics.balanced_accuracy_score(y_train, y_pred)
train_mcc = metrics.matthews_corrcoef(y_train, y_pred)
train_cf = metrics.confusion_matrix(y_train, y_pred)

# calculate statistical metrics for val set
val_f1 = metrics.f1_score(y_val, y_val_pred, average = 'weighted')
val_ba = metrics.balanced_accuracy_score(y_val, y_val_pred)
val_mcc = metrics.matthews_corrcoef(y_val, y_val_pred)
val_cf = metrics.confusion_matrix(y_val, y_val_pred)

# calculate statistical metrics for testing set
test_f1 = metrics.f1_score(y_test, y_test_pred, average = 'weighted')
test_ba = metrics.balanced_accuracy_score(y_test, y_test_pred)
test_mcc = metrics.matthews_corrcoef(y_test, y_test_pred)
test_cf = metrics.confusion_matrix(y_test, y_test_pred)

print(f'TRAIN scores \n')
print(f'f1: {train_f1:.3f}')
print(f'balanced accuracy: {train_ba:.3f}')
print(f'matthews corrcoeff: {train_mcc:.3f}')
print(f'cf:\n{train_cf}')
print('-----------')
print(f'VAL scores \n')
print(f'f1: {val_f1:.3f}')
print(f'balanced accuracy: {val_ba:.3f}')
print(f'matthews corrcoeff: {val_mcc:.3f}')
print(f'cf:\n{val_cf}')
print('-----------')
#print(f'TEST scores \n')
#print(f'f1: {test_f1:.3f}')
#print(f'balanced accuracy: {test_ba:.3f}')
#print(f'matthews corrcoeff: {test_mcc:.3f}')
#print(f'cf:\n{test_cf}')
#print('')

# %% [markdown]
# # svm

# %%
X_train, X_val, X_test, y_train, y_val, y_test, descnm = data_preprocessing(data_da)

# %% [markdown]
# ## linear

# %%
start_time = time.time()
model_linear = pd.DataFrame(find_model(X_train, y_train, X_val, y_val, algorithm='SVC', kernel='linear'))
model_linear.to_csv('da_svm_linear.csv')
end_time = time.time()
duration_linear = end_time-start_time
print(f"Operation took {duration_linear} seconds.")

# %%
model_linear
# Out:
#               sampling                      scaling  train_accuracy  train_f1  \
# 0                SMOTE                         none           0.634     0.626
# 4                SMOTE                   Normalizer           0.634     0.626
# 11  RandomUnderSampler                         none           0.634     0.626
# 15  RandomUnderSampler                   Normalizer           0.634     0.626
# 22   RandomOverSampler                         none           0.634     0.626
# 26   RandomOverSampler                   Normalizer           0.634     0.626
# 33         no_sampling                         none           0.634     0.626
# 37         no_sampling                   Normalizer           0.634     0.626
# 8                SMOTE    MaxAbsScaler + Normalizer           0.627     0.616
# 9                SMOTE    MinMaxScaler + Normalizer           0.627     0.616
# 19  RandomUnderSampler    MaxAbsScaler + Normalizer           0.627     0.616
# 20  RandomUnderSampler    MinMaxScaler + Normalizer           0.627     0.616
# 30   RandomOverSampler    MaxAbsScaler + Normalizer           0.627     0.616
# 31   RandomOverSampler    MinMaxScaler + Normalizer           0.627     0.616
# 41         no_sampling    MaxAbsScaler + Normalizer           0.627     0.616
# 42         no_sampling    MinMaxScaler + Normalizer           0.627     0.616
# 10               SMOTE  StandardScaler + Normalizer           0.647     0.656
# 21  RandomUnderSampler  StandardScaler + Normalizer           0.647     0.656
# 32   RandomOverSampler  StandardScaler + Normalizer           0.647     0.656
# 43         no_sampling  StandardScaler + Normalizer           0.647     0.656
# 3                SMOTE               StandardScaler           0.661     0.659
# 7                SMOTE  Normalizer + StandardScaler           0.661     0.659
# 14  RandomUnderSampler               StandardScaler           0.661     0.659
# 18  RandomUnderSampler  Normalizer + StandardScaler           0.661     0.659
# 25   RandomOverSampler               StandardScaler           0.661     0.659
# 29   RandomOverSampler  Normalizer + StandardScaler           0.661     0.659
# 36         no_sampling               StandardScaler           0.661     0.659
# 40         no_sampling  Normalizer + StandardScaler           0.661     0.659
# 1                SMOTE                 MaxAbsScaler           0.641     0.642
# 2                SMOTE                 MinMaxScaler           0.641     0.642
# 5                SMOTE    Normalizer + MaxAbsScaler           0.641     0.642
# 6                SMOTE    Normalizer + MinMaxScaler           0.641     0.642
# 12  RandomUnderSampler                 MaxAbsScaler           0.641     0.642
# 13  RandomUnderSampler                 MinMaxScaler           0.641     0.642
# 16  RandomUnderSampler    Normalizer + MaxAbsScaler           0.641     0.642
# 17  RandomUnderSampler    Normalizer + MinMaxScaler           0.641     0.642
# 23   RandomOverSampler                 MaxAbsScaler           0.641     0.642
# 24   RandomOverSampler                 MinMaxScaler           0.641     0.642
# 27   RandomOverSampler    Normalizer + MaxAbsScaler           0.641     0.642
# 28   RandomOverSampler    Normalizer + MinMaxScaler           0.641     0.642
# 34         no_sampling                 MaxAbsScaler           0.641     0.642
# 35         no_sampling                 MinMaxScaler           0.641     0.642
# 38         no_sampling    Normalizer + MaxAbsScaler           0.641     0.642
# 39         no_sampling    Normalizer + MinMaxScaler           0.641     0.642
#
#     train_ba  train_mcc                train_cf  val_accuracy  val_f1  val_ba  \
# 0      0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 4      0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 11     0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 15     0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 22     0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 26     0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 33     0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 37     0.634      0.268  [[142, 75], [84, 133]]         0.440   0.560   0.641
# 8      0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 9      0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 19     0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 20     0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 30     0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 31     0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 41     0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 42     0.627      0.254  [[142, 75], [87, 130]]         0.549   0.680   0.633
# 10     0.647      0.295  [[135, 82], [71, 146]]         0.773   0.867   0.582
# 21     0.647      0.295  [[135, 82], [71, 146]]         0.773   0.867   0.582
# 32     0.647      0.295  [[135, 82], [71, 146]]         0.773   0.867   0.582
# 43     0.647      0.295  [[135, 82], [71, 146]]         0.773   0.867   0.582
# 3      0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 7      0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 14     0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 18     0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 25     0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 29     0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 36     0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 40     0.661      0.323  [[145, 72], [75, 142]]         0.907   0.951   0.500
# 1      0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 2      0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 5      0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 6      0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 12     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 13     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 16     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 17     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 23     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 24     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 27     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 28     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 34     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 35     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 38     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
# 39     0.641      0.281  [[138, 79], [77, 140]]         0.895   0.944   0.500
#
#     val_mcc                  val_cf
# 0     0.170   [[64, 8], [424, 275]]
# 4     0.170   [[64, 8], [424, 275]]
# 11    0.170   [[64, 8], [424, 275]]
# 15    0.170   [[64, 8], [424, 275]]
# 22    0.170   [[64, 8], [424, 275]]
# 26    0.170   [[64, 8], [424, 275]]
# 33    0.170   [[64, 8], [424, 275]]
# 37    0.170   [[64, 8], [424, 275]]
# 8     0.154  [[53, 19], [329, 370]]
# 9     0.154  [[53, 19], [329, 370]]
# 19    0.154  [[53, 19], [329, 370]]
# 20    0.154  [[53, 19], [329, 370]]
# 30    0.154  [[53, 19], [329, 370]]
# 31    0.154  [[53, 19], [329, 370]]
# 41    0.154  [[53, 19], [329, 370]]
# 42    0.154  [[53, 19], [329, 370]]
# 10    0.120  [[25, 47], [128, 571]]
# 21    0.120  [[25, 47], [128, 571]]
# 32    0.120  [[25, 47], [128, 571]]
# 43    0.120  [[25, 47], [128, 571]]
# 3     0.000     [[0, 72], [0, 699]]
# 7     0.000     [[0, 72], [0, 699]]
# 14    0.000     [[0, 72], [0, 699]]
# 18    0.000     [[0, 72], [0, 699]]
# 25    0.000     [[0, 72], [0, 699]]
# 29    0.000     [[0, 72], [0, 699]]
# 36    0.000     [[0, 72], [0, 699]]
# 40    0.000     [[0, 72], [0, 699]]
# 1    -0.001    [[1, 71], [10, 689]]
# 2    -0.001    [[1, 71], [10, 689]]
# 5    -0.001    [[1, 71], [10, 689]]
# 6    -0.001    [[1, 71], [10, 689]]
# 12   -0.001    [[1, 71], [10, 689]]
# 13   -0.001    [[1, 71], [10, 689]]
# 16   -0.001    [[1, 71], [10, 689]]
# 17   -0.001    [[1, 71], [10, 689]]
# 23   -0.001    [[1, 71], [10, 689]]
# 24   -0.001    [[1, 71], [10, 689]]
# 27   -0.001    [[1, 71], [10, 689]]
# 28   -0.001    [[1, 71], [10, 689]]
# 34   -0.001    [[1, 71], [10, 689]]
# 35   -0.001    [[1, 71], [10, 689]]
# 38   -0.001    [[1, 71], [10, 689]]
# 39   -0.001    [[1, 71], [10, 689]]

# %%
model_linear_melted = pd.melt(model_linear, id_vars=['sampling', 'scaling'], value_vars=['train_accuracy', 'train_f1', 'train_ba', 'train_mcc', 'val_accuracy', 'val_f1', 'val_ba', 'val_mcc',], var_name='metrics', value_name='value')
model_linear_melted = model_linear_melted.drop(model_linear_melted[model_linear_melted['metrics'].isin(['train_accuracy', 'val_accuracy'])].index)
model_linear_melted['set'] = np.where(model_linear_melted['metrics'].str.startswith('train'), 'train', 'val')
model_linear_melted['met'] = np.where(model_linear_melted['metrics'].str.endswith('f1'), 'f1', 
                                     np.where(model_linear_melted['metrics'].str.endswith('ba'), 'ba', 'mcc'))
model_linear_melted['sampling'] = np.where(model_linear_melted['sampling'].str.startswith('RandomOver'), 'Random Oversampler', 
                                          np.where(model_linear_melted['sampling'].str.startswith('RandomUnder'), 'Random Undersampler', 
                                                   np.where(model_linear_melted['sampling'].str.startswith('SMOTE'), 'SMOTE', 'No Sampling'
                                          )))
model_linear_melted = model_linear_melted.drop(columns=['metrics'])#.sort_values(['sampling', 'set'])
model_linear_melted
# Out:
#                 sampling                    scaling  value    set  met
# 44                 SMOTE                       none  0.626  train   f1
# 45                 SMOTE                 Normalizer  0.626  train   f1
# 46   Random Undersampler                       none  0.626  train   f1
# 47   Random Undersampler                 Normalizer  0.626  train   f1
# 48    Random Oversampler                       none  0.626  train   f1
# ..                   ...                        ...    ...    ...  ...
# 347   Random Oversampler  Normalizer + MinMaxScaler -0.001    val  mcc
# 348          No Sampling               MaxAbsScaler -0.001    val  mcc
# 349          No Sampling               MinMaxScaler -0.001    val  mcc
# 350          No Sampling  Normalizer + MaxAbsScaler -0.001    val  mcc
# 351          No Sampling  Normalizer + MinMaxScaler -0.001    val  mcc
#
# [264 rows x 5 columns]

# %%
sns.violinplot(data=model_linear_melted[model_linear_melted['met']=='mcc'], 
               x='sampling', y='value', hue='set',)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('MCC Values for Baseline Model, linear kernel')
plt.show()

# %% [markdown]
# ## poly

# %%
start_time = time.time()
model_poly = pd.DataFrame(find_model(X_train, y_train, X_val, y_val, algorithm='SVC', kernel='poly'))
model_poly.to_csv('da_svm_poly.csv')
end_time = time.time()
duration_poly = end_time-start_time
print(f"Operation took {duration_poly} seconds.")
# Out:
# Operation took 4.201333999633789 seconds.

# %%
model_poly_melted = pd.melt(model_poly, id_vars=['sampling', 'scaling'], value_vars=['train_accuracy', 'train_f1', 'train_ba', 'train_mcc', 'val_accuracy', 'val_f1', 'val_ba', 'val_mcc',], var_name='metrics', value_name='value')
model_poly_melted = model_poly_melted.drop(model_poly_melted[model_poly_melted['metrics'].isin(['train_accuracy', 'val_accuracy'])].index)
model_poly_melted['set'] = np.where(model_poly_melted['metrics'].str.startswith('train'), 'train', 'val')
model_poly_melted['met'] = np.where(model_poly_melted['metrics'].str.endswith('f1'), 'f1', 
                                     np.where(model_poly_melted['metrics'].str.endswith('ba'), 'ba', 'mcc'))
model_poly_melted['sampling'] = np.where(model_poly_melted['sampling'].str.startswith('RandomOver'), 'Random Oversampler', 
                                          np.where(model_poly_melted['sampling'].str.startswith('RandomUnder'), 'Random Undersampler', 
                                                   np.where(model_poly_melted['sampling'].str.startswith('SMOTE'), 'SMOTE', 'No Sampling'
                                          )))
model_poly_melted = model_poly_melted.drop(columns=['metrics']).sort_values(['sampling', 'set'])
model_poly_melted
# Out:
#         sampling                      scaling  value    set  met
# 47   No Sampling  StandardScaler + Normalizer  0.910  train   f1
# 54   No Sampling               StandardScaler  0.747  train   f1
# 55   No Sampling  Normalizer + StandardScaler  0.747  train   f1
# 62   No Sampling                         none  0.796  train   f1
# 63   No Sampling                   Normalizer  0.796  train   f1
# ..           ...                          ...    ...    ...  ...
# 329        SMOTE    MinMaxScaler + Normalizer -0.012    val  mcc
# 336        SMOTE                 MaxAbsScaler -0.016    val  mcc
# 337        SMOTE                 MinMaxScaler -0.016    val  mcc
# 338        SMOTE    Normalizer + MaxAbsScaler -0.016    val  mcc
# 339        SMOTE    Normalizer + MinMaxScaler -0.016    val  mcc
#
# [264 rows x 5 columns]

# %% [markdown]
# ## rbf

# %%
start_time = time.time()
model_rbf = pd.DataFrame(find_model(X_train, y_train, X_val, y_val, algorithm='SVC', kernel='rbf'))
model_rbf.to_csv('da_svm_rbf.csv')
end_time = time.time()
duration_rbf = end_time-start_time
print(f"Operation took {duration_rbf} seconds.")
# Out:
# Operation took 8.249082803726196 seconds.

# %%
model_rbf
# Out:
#               sampling                      scaling  train_accuracy  train_f1  \
# 10               SMOTE  StandardScaler + Normalizer           0.832     0.826
# 21  RandomUnderSampler  StandardScaler + Normalizer           0.832     0.826
# 32   RandomOverSampler  StandardScaler + Normalizer           0.832     0.826
# 43         no_sampling  StandardScaler + Normalizer           0.832     0.826
# 3                SMOTE               StandardScaler           0.802     0.790
# 7                SMOTE  Normalizer + StandardScaler           0.802     0.790
# 14  RandomUnderSampler               StandardScaler           0.802     0.790
# 18  RandomUnderSampler  Normalizer + StandardScaler           0.802     0.790
# 25   RandomOverSampler               StandardScaler           0.802     0.790
# 29   RandomOverSampler  Normalizer + StandardScaler           0.802     0.790
# 36         no_sampling               StandardScaler           0.802     0.790
# 40         no_sampling  Normalizer + StandardScaler           0.802     0.790
# 0                SMOTE                         none           0.728     0.715
# 4                SMOTE                   Normalizer           0.728     0.715
# 11  RandomUnderSampler                         none           0.728     0.715
# 15  RandomUnderSampler                   Normalizer           0.728     0.715
# 22   RandomOverSampler                         none           0.728     0.715
# 26   RandomOverSampler                   Normalizer           0.728     0.715
# 33         no_sampling                         none           0.728     0.715
# 37         no_sampling                   Normalizer           0.728     0.715
# 1                SMOTE                 MaxAbsScaler           0.710     0.703
# 2                SMOTE                 MinMaxScaler           0.710     0.703
# 5                SMOTE    Normalizer + MaxAbsScaler           0.710     0.703
# 6                SMOTE    Normalizer + MinMaxScaler           0.710     0.703
# 12  RandomUnderSampler                 MaxAbsScaler           0.710     0.703
# 13  RandomUnderSampler                 MinMaxScaler           0.710     0.703
# 16  RandomUnderSampler    Normalizer + MaxAbsScaler           0.710     0.703
# 17  RandomUnderSampler    Normalizer + MinMaxScaler           0.710     0.703
# 23   RandomOverSampler                 MaxAbsScaler           0.710     0.703
# 24   RandomOverSampler                 MinMaxScaler           0.710     0.703
# 27   RandomOverSampler    Normalizer + MaxAbsScaler           0.710     0.703
# 28   RandomOverSampler    Normalizer + MinMaxScaler           0.710     0.703
# 34         no_sampling                 MaxAbsScaler           0.710     0.703
# 35         no_sampling                 MinMaxScaler           0.710     0.703
# 38         no_sampling    Normalizer + MaxAbsScaler           0.710     0.703
# 39         no_sampling    Normalizer + MinMaxScaler           0.710     0.703
# 8                SMOTE    MaxAbsScaler + Normalizer           0.705     0.702
# 9                SMOTE    MinMaxScaler + Normalizer           0.705     0.702
# 19  RandomUnderSampler    MaxAbsScaler + Normalizer           0.705     0.702
# 20  RandomUnderSampler    MinMaxScaler + Normalizer           0.705     0.702
# 30   RandomOverSampler    MaxAbsScaler + Normalizer           0.705     0.702
# 31   RandomOverSampler    MinMaxScaler + Normalizer           0.705     0.702
# 41         no_sampling    MaxAbsScaler + Normalizer           0.705     0.702
# 42         no_sampling    MinMaxScaler + Normalizer           0.705     0.702
#
#     train_ba  train_mcc                train_cf  val_accuracy  val_f1  val_ba  \
# 10     0.832      0.665  [[188, 29], [44, 173]]         0.093     0.0     0.5
# 21     0.832      0.665  [[188, 29], [44, 173]]         0.093     0.0     0.5
# 32     0.832      0.665  [[188, 29], [44, 173]]         0.093     0.0     0.5
# 43     0.832      0.665  [[188, 29], [44, 173]]         0.093     0.0     0.5
# 3      0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 7      0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 14     0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 18     0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 25     0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 29     0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 36     0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 40     0.802      0.607  [[186, 31], [55, 162]]         0.093     0.0     0.5
# 0      0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 4      0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 11     0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 15     0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 22     0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 26     0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 33     0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 37     0.728      0.458  [[168, 49], [69, 148]]         0.093     0.0     0.5
# 1      0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 2      0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 5      0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 6      0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 12     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 13     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 16     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 17     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 23     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 24     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 27     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 28     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 34     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 35     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 38     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 39     0.710      0.420  [[159, 58], [68, 149]]         0.093     0.0     0.5
# 8      0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
# 9      0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
# 19     0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
# 20     0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
# 30     0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
# 31     0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
# 41     0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
# 42     0.705      0.410  [[155, 62], [66, 151]]         0.093     0.0     0.5
#
#     val_mcc               val_cf
# 10      0.0  [[72, 0], [699, 0]]
# 21      0.0  [[72, 0], [699, 0]]
# 32      0.0  [[72, 0], [699, 0]]
# 43      0.0  [[72, 0], [699, 0]]
# 3       0.0  [[72, 0], [699, 0]]
# 7       0.0  [[72, 0], [699, 0]]
# 14      0.0  [[72, 0], [699, 0]]
# 18      0.0  [[72, 0], [699, 0]]
# 25      0.0  [[72, 0], [699, 0]]
# 29      0.0  [[72, 0], [699, 0]]
# 36      0.0  [[72, 0], [699, 0]]
# 40      0.0  [[72, 0], [699, 0]]
# 0       0.0  [[72, 0], [699, 0]]
# 4       0.0  [[72, 0], [699, 0]]
# 11      0.0  [[72, 0], [699, 0]]
# 15      0.0  [[72, 0], [699, 0]]
# 22      0.0  [[72, 0], [699, 0]]
# 26      0.0  [[72, 0], [699, 0]]
# 33      0.0  [[72, 0], [699, 0]]
# 37      0.0  [[72, 0], [699, 0]]
# 1       0.0  [[72, 0], [699, 0]]
# 2       0.0  [[72, 0], [699, 0]]
# 5       0.0  [[72, 0], [699, 0]]
# 6       0.0  [[72, 0], [699, 0]]
# 12      0.0  [[72, 0], [699, 0]]
# 13      0.0  [[72, 0], [699, 0]]
# 16      0.0  [[72, 0], [699, 0]]
# 17      0.0  [[72, 0], [699, 0]]
# 23      0.0  [[72, 0], [699, 0]]
# 24      0.0  [[72, 0], [699, 0]]
# 27      0.0  [[72, 0], [699, 0]]
# 28      0.0  [[72, 0], [699, 0]]
# 34      0.0  [[72, 0], [699, 0]]
# 35      0.0  [[72, 0], [699, 0]]
# 38      0.0  [[72, 0], [699, 0]]
# 39      0.0  [[72, 0], [699, 0]]
# 8       0.0  [[72, 0], [699, 0]]
# 9       0.0  [[72, 0], [699, 0]]
# 19      0.0  [[72, 0], [699, 0]]
# 20      0.0  [[72, 0], [699, 0]]
# 30      0.0  [[72, 0], [699, 0]]
# 31      0.0  [[72, 0], [699, 0]]
# 41      0.0  [[72, 0], [699, 0]]
# 42      0.0  [[72, 0], [699, 0]]

# %%
model_rbf_melted = pd.melt(model_rbf, id_vars=['sampling', 'scaling'], value_vars=['train_accuracy', 'train_f1', 'train_ba', 'train_mcc', 'val_accuracy', 'val_f1', 'val_ba', 'val_mcc',], var_name='metrics', value_name='value')
model_rbf_melted = model_rbf_melted.drop(model_rbf_melted[model_rbf_melted['metrics'].isin(['train_accuracy', 'val_accuracy'])].index)
model_rbf_melted['set'] = np.where(model_rbf_melted['metrics'].str.startswith('train'), 'train', 'val')
model_rbf_melted['met'] = np.where(model_rbf_melted['metrics'].str.endswith('f1'), 'f1', 
                                     np.where(model_rbf_melted['metrics'].str.endswith('ba'), 'ba', 'mcc'))
model_rbf_melted['sampling'] = np.where(model_rbf_melted['sampling'].str.startswith('RandomOver'), 'Random Oversampler', 
                                          np.where(model_rbf_melted['sampling'].str.startswith('RandomUnder'), 'Random Undersampler', 
                                                   np.where(model_rbf_melted['sampling'].str.startswith('SMOTE'), 'SMOTE', 'No Sampling'
                                          )))
model_rbf_melted = model_rbf_melted.drop(columns=['metrics']).sort_values(['sampling', 'set'])
model_rbf_melted
# Out:
#         sampling                      scaling  value    set  met
# 47   No Sampling  StandardScaler + Normalizer  0.826  train   f1
# 54   No Sampling               StandardScaler  0.790  train   f1
# 55   No Sampling  Normalizer + StandardScaler  0.790  train   f1
# 62   No Sampling                         none  0.715  train   f1
# 63   No Sampling                   Normalizer  0.715  train   f1
# ..           ...                          ...    ...    ...  ...
# 329        SMOTE                 MinMaxScaler  0.000    val  mcc
# 330        SMOTE    Normalizer + MaxAbsScaler  0.000    val  mcc
# 331        SMOTE    Normalizer + MinMaxScaler  0.000    val  mcc
# 344        SMOTE    MaxAbsScaler + Normalizer  0.000    val  mcc
# 345        SMOTE    MinMaxScaler + Normalizer  0.000    val  mcc
#
# [264 rows x 5 columns]

# %% [markdown]
# ## sigmoid

# %%
start_time = time.time()
model_sigmoid = pd.DataFrame(find_model(X_train, y_train, X_val, y_val, algorithm='SVC', kernel='sigmoid'))
model_sigmoid.to_csv('da_svm_sigmoid.csv')
end_time = time.time()
duration_sigmoid = end_time-start_time
print(f"Operation took {duration_sigmoid} seconds.")
# Out:
# Operation took 6.985504865646362 seconds.

# %%
model_sigmoid_melted = pd.melt(model_sigmoid, id_vars=['sampling', 'scaling'], value_vars=['train_accuracy', 'train_f1', 'train_ba', 'train_mcc', 'val_accuracy', 'val_f1', 'val_ba', 'val_mcc',], var_name='metrics', value_name='value')
model_sigmoid_melted = model_sigmoid_melted.drop(model_sigmoid_melted[model_sigmoid_melted['metrics'].isin(['train_accuracy', 'val_accuracy'])].index)
model_sigmoid_melted['set'] = np.where(model_sigmoid_melted['metrics'].str.startswith('train'), 'train', 'val')
model_sigmoid_melted['met'] = np.where(model_sigmoid_melted['metrics'].str.endswith('f1'), 'f1', 
                                     np.where(model_sigmoid_melted['metrics'].str.endswith('ba'), 'ba', 'mcc'))
model_sigmoid_melted['sampling'] = np.where(model_sigmoid_melted['sampling'].str.startswith('RandomOver'), 'Random Oversampler', 
                                          np.where(model_sigmoid_melted['sampling'].str.startswith('RandomUnder'), 'Random Undersampler', 
                                                   np.where(model_sigmoid_melted['sampling'].str.startswith('SMOTE'), 'SMOTE', 'No Sampling'
                                          )))
model_sigmoid_melted = model_sigmoid_melted.drop(columns=['metrics']).sort_values(['sampling', 'set'])
model_sigmoid_melted
# Out:
#         sampling                      scaling  value    set  met
# 47   No Sampling  StandardScaler + Normalizer  0.575  train   f1
# 54   No Sampling               StandardScaler  0.507  train   f1
# 55   No Sampling  Normalizer + StandardScaler  0.507  train   f1
# 62   No Sampling                         none  0.221  train   f1
# 63   No Sampling                   Normalizer  0.221  train   f1
# ..           ...                          ...    ...    ...  ...
# 329        SMOTE                 MinMaxScaler  0.000    val  mcc
# 330        SMOTE    Normalizer + MaxAbsScaler  0.000    val  mcc
# 331        SMOTE    Normalizer + MinMaxScaler  0.000    val  mcc
# 344        SMOTE    MaxAbsScaler + Normalizer  0.000    val  mcc
# 345        SMOTE    MinMaxScaler + Normalizer  0.000    val  mcc
#
# [264 rows x 5 columns]

# %% [markdown]
# ## plot for all kernels

# %%
fig, ax = plt.subplots(ncols=4, nrows=2, figsize=(16, 6), sharex=True, sharey=True)

ax[0, 0].set_title(f'linear, t = {round(duration_linear, 2)} s')
ax[0, 1].set_title(f'poly, t = {round(duration_poly, 2)} s')
ax[0, 2].set_title(f'rbf, t = {round(duration_rbf, 2)} s')
ax[0, 3].set_title(f'sigmoid, t = {round(duration_sigmoid, 2)} s')

for i, j in enumerate([model_linear_melted, model_poly_melted, model_rbf_melted, model_sigmoid_melted]):
    sns.violinplot(data=j[j['met']=='mcc'], x='sampling', y='value', hue='set', ax=ax[0, i])
    sns.violinplot(data=j[j['met']=='ba'], x='sampling', y='value', hue='set', ax=ax[1, i])
    ax[0, i].axhline(y=0, color='r', linestyle='--')
    ax[1, i].axhline(y=0.5, color='r', linestyle='--')
    ax[1, i].set_xticklabels(ax[1, i].get_xticklabels(), rotation=90, ha='center')
    ax[0, i].set_xlabel('')
    ax[1, i].set_xlabel('')
    ax[0, i].set_ylabel('')
    ax[1, i].set_ylabel('')
    ax[0, 0].set_ylabel('Matthews Correlation\nCoefficient')
    ax[1, 0].set_ylabel('Balanced Accuracy')
plt.setp(ax,
         yticks=[-0.2, 0, 0.2, 0.4, 0.6, 0.8, 1],
         xticklabels=['No\nSampling',  'Random\nOversampling', 'Random\nUndersampling', 'SMOTE'],
)
plt.show()

# %% [markdown]
# ## feature importance

# %% [markdown]
# ## hyperparameter tuninr

# %% [markdown]
# # rf
